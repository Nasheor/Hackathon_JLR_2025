# %%
import json
from pathlib import Path

RAW_DATA_DIR = Path("../data/raw")


with open(RAW_DATA_DIR / "post_processed.json", "r") as f:
    data = json.load(f)

hash_map = {}

for item in data:
    if '@Abstraction' in item:
        del item['@Abstraction']
    if '@Structure' in item:
        del item['@Structure']
    if '@Status' in item:
        del item['@Status']
    if 'Related_Weaknesses' in item:
        del item['Related_Weaknesses']
    if 'Modes_of_Introduction' in item:
        del item['Modes_of_Introduction']
    if 'Likelihood_Of_Exploit' in item:
        del item['Likelihood_Of_Exploit']
    if 'References' in item:
        del item['References']
    if 'Mapping_Notes' in item:
        del item['Mapping_Notes']
    if 'Content_History' in item:
        del item['Content_History']
    if 'Notes' in item:
        del item['Notes']
    if 'Related_Attack_Patterns' in item:
        del item['Related_Attack_Patterns']
    if 'Taxonomy_Mappings' in item:
        del item['Taxonomy_Mappings']
    hash_map[item['@ID']] = item

with open(RAW_DATA_DIR / "post_processed_map.json", "w") as f:
    json.dump(hash_map, f, indent=2, ensure_ascii=False)
print(f"Processed {len(data)} items into a hash map.")
# Out:
# Processed 968 items into a hash map.

# %%
from pydantic import BaseModel, Field
from google import genai

class CodePairResponse(BaseModel):
    cwe_id: str = Field(
        ...,
        description="The CWE ID associated with the code pair."
    )
    vulnerable_code: str = Field(
        ...,
        description="The vulnerable code snippet that contains a security flaw."
    )
    fixed_code: str = Field(
        ...,
        description="The fixed code snippet that resolves the security flaw."
    )

with open('token', 'r') as file:
    token = file.read().strip()

client = genai.Client(api_key=token)

def generate_prompt(cwe_id: str, examples: list[dict] | None = None) -> str:
    prompt = f"""
You are an expert vulnerability researcher in automotive software security.
your task is to generate a code pair that demonstrates a security flaw and its fix based on the provided CWE ID.
the code pair should include:
1. A vulnerable code snippet that contains a security flaw related to the given CWE ID.
2. A fixed code snippet that resolves the security flaw.
The code snippets should be in C / C++ programming language.
The code should not contain any comments or explanations, just the code snippets.
Code snippets should not be evidently vulnerable, but should contain a subtle flaw that can be exploited. in other words, the code should not be obviously insecure, but should contain a flaw that can be exploited by an attacker.
Make the code snippet complex, ideally as a part of a larger function, class or context.
The code snippets should be realistic and relevant to the automotive domain.
CWE information: {hash_map[cwe_id]}
"""
    if examples:
        prompt += f"\nHere is some examples of a previously generated code pairs for the CWE-{cwe_id}:\n{examples}\n"
        prompt += f"\nGenerate a new code pair for CWE-{cwe_id}:\n that does not resemble the examples, but constitutes the same CWE in a completely different way.\n"
        prompt += f"\nThere should be no overlap with the examples, but the code should still demonstrate the same CWE.\n"
        prompt += f"\nthink creately about where to put this vulnerability, so your code does not resemble examples.\n"
        prompt += f"\nYou MUST AVOID using the same vulnerable functions (e.g., strcpy, sprintf, memcpy etc.) as in the examples. Try to come up with the new way to introduce the vulnerability.\n"
    return prompt.strip()

def get_code_pair(cwe_id: str, examples: dict | None = None) -> CodePairResponse:
    try:
        response = client.models.generate_content(
            model="gemini-2.5-flash-preview-05-20",
            contents=generate_prompt(cwe_id, examples),
            config={
                "response_mime_type": "application/json",
                "response_schema": CodePairResponse,
            },
        )
        # if server error, return empty list
    except genai.errors.ServerError as e:
        print(f"Server error: {e}")
        return None
    return response.parsed

# %%
import random

examples = []
cwe_id = "119"
json_out_structure = []

with open(f"cwe_{cwe_id}_code_pairs.json", "r") as f:
    try:
        json_out_structure = json.load(f)
    except json.JSONDecodeError:
        json_out_structure = []

for item in json_out_structure:
    examples.append({'vulnerable_code': item['vulnerable_code'], 'fixed_code': item['fixed_code']})

for i in range(100 - len(examples)):
    pair = get_code_pair(cwe_id, random.choices(examples, k=8) if examples else None)
    if pair:
        examples.append({'vulnerable_code': pair.vulnerable_code, 'fixed_code': pair.fixed_code})
        print(f"CWE ID: {pair.cwe_id}")
        print("\nVulnerable Code:")
        print(pair.vulnerable_code)
        print("\nFixed Code:")
        print(pair.fixed_code)
        print("\n" + "="*50 + "\n")
        json_out_structure.append({
            "cwe_id": pair.cwe_id,
            "cwe_description": hash_map[cwe_id]['Extended_Description'] if 'Extended_Description' in hash_map[cwe_id] else hash_map[cwe_id]['Description'],
            "vulnerable_code": pair.vulnerable_code,
            "fixed_code": pair.fixed_code,
            "analysis": "", # Placeholder for analysis later
        })
        with open(f"cwe_{cwe_id}_code_pairs.json", "w") as f:
            json.dump(json_out_structure, f, indent=2, ensure_ascii=False)
    else:
        print("Failed to retrieve code pair.")
# Out:
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# #define MAX_STORED_TELEMETRY_RECORDS_DATA_SIZE 256
# #define MAX_INCOMING_PACKET_SIZE 512
#
# static uint8_t g_telemetryStorageBuffer[MAX_STORED_TELEMETRY_RECORDS_DATA_SIZE];
# static uint16_t g_currentStorageWriteOffset = 0;
#
# void initTelemetryStorage() {
#     memset(g_telemetryStorageBuffer, 0, MAX_STORED_TELEMETRY_RECORDS_DATA_SIZE);
#     g_currentStorageWriteOffset = 0;
# }
#
# int processTelemetryDataPacket(const uint8_t* packet_data, uint16_t packet_len) {
#     if (packet_data == NULL || packet_len == 0 || packet_len > MAX_INCOMING_PACKET_SIZE) {
#         return -1;
#     }
#
#     uint16_t current_packet_read_offset = 0;
#
#     while (current_packet_read_offset < packet_len) {
#         if (current_packet_read_offset + 2 > packet_len) {
#             return -1;
#         }
#
#         uint8_t record_id = packet_data[current_packet_read_offset];
#         uint8_t data_len = packet_data[current_packet_read_offset + 1];
#
#         if (current_packet_read_offset + 2 + data_len > packet_len) {
#             return -1;
#         }
#
#         const uint8_t* record_data_ptr = packet_data + current_packet_read_offset + 2;
#
#         g_telemetryStorageBuffer[g_currentStorageWriteOffset] = record_id;
#         g_currentStorageWriteOffset++;
#
#         g_telemetryStorageBuffer[g_currentStorageWriteOffset] = data_len;
#         g_currentStorageWriteOffset++;
#
#         for (int i = 0; i < data_len; ++i) {
#             g_telemetryStorageBuffer[g_currentStorageWriteOffset + i] = record_data_ptr[i];
#         }
#         g_currentStorageWriteOffset += data_len;
#
#         current_packet_read_offset += 2 + data_len;
#     }
#
#     return 0;
# }
#
# void systemReceiveTelemetry(const uint8_t* raw_telemetry_packet, uint16_t packet_size) {
#     if (g_currentStorageWriteOffset == 0) {
#         initTelemetryStorage();
#     }
#     processTelemetryDataPacket(raw_telemetry_packet, packet_size);
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
#
# #define MAX_STORED_TELEMETRY_RECORDS_DATA_SIZE 256
# #define MAX_INCOMING_PACKET_SIZE 512
#
# static uint8_t g_telemetryStorageBuffer[MAX_STORED_TELEMETRY_RECORDS_DATA_SIZE];
# static uint16_t g_currentStorageWriteOffset = 0;
#
# void initTelemetryStorage() {
#     memset(g_telemetryStorageBuffer, 0, MAX_STORED_TELEMETRY_RECORDS_DATA_SIZE);
#     g_currentStorageWriteOffset = 0;
# }
#
# int processTelemetryDataPacket(const uint8_t* packet_data, uint16_t packet_len) {
#     if (packet_data == NULL || packet_len == 0 || packet_len > MAX_INCOMING_PACKET_SIZE) {
#         return -1;
#     }
#
#     uint16_t current_packet_read_offset = 0;
#
#     while (current_packet_read_offset < packet_len) {
#         if (current_packet_read_offset + 2 > packet_len) {
#             return -1;
#         }
#
#         uint8_t record_id = packet_data[current_packet_read_offset];
#         uint8_t data_len = packet_data[current_packet_read_offset + 1];
#
#         if (current_packet_read_offset + 2 + data_len > packet_len) {
#             return -1;
#         }
#
#         uint16_t record_storage_size = 2 + data_len;
#
#         if (g_currentStorageWriteOffset + record_storage_size > MAX_STORED_TELEMETRY_RECORDS_DATA_SIZE) {
#             return -2;
#         }
#
#         const uint8_t* record_data_ptr = packet_data + current_packet_read_offset + 2;
#
#         g_telemetryStorageBuffer[g_currentStorageWriteOffset] = record_id;
#         g_currentStorageWriteOffset++;
#
#         g_telemetryStorageBuffer[g_currentStorageWriteOffset] = data_len;
#         g_currentStorageWriteOffset++;
#
#         for (int i = 0; i < data_len; ++i) {
#             g_telemetryStorageBuffer[g_currentStorageWriteOffset + i] = record_data_ptr[i];
#         }
#         g_currentStorageWriteOffset += data_len;
#
#         current_packet_read_offset += 2 + data_len;
#     }
#
#     return 0;
# }
#
# void systemReceiveTelemetry(const uint8_t* raw_telemetry_packet, uint16_t packet_size) {
#     if (g_currentStorageWriteOffset == 0) {
#         initTelemetryStorage();
#     }
#     processTelemetryDataPacket(raw_telemetry_packet, packet_size);
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# #define MAX_DTC_METADATA_PROTO_MAX 60
# #define MAX_INTERNAL_DTC_METADATA_SIZE 30
#
# #define MAX_LOGGED_DTC_RECORDS 20
# #define DTC_RECORD_FIXED_SIZE (sizeof(uint16_t) + sizeof(uint8_t) + sizeof(uint8_t))
# #define SINGLE_DTC_RECORD_STORAGE_SIZE (DTC_RECORD_FIXED_SIZE + MAX_INTERNAL_DTC_METADATA_SIZE)
# #define DTC_LOG_BUFFER_TOTAL_SIZE (MAX_LOGGED_DTC_RECORDS * SINGLE_DTC_RECORD_STORAGE_SIZE)
#
# typedef struct {
#     uint16_t dtc_id;
#     uint8_t status_byte;
#     uint8_t metadata_len;
#     uint8_t metadata[MAX_INTERNAL_DTC_METADATA_SIZE];
# } DTCRecord;
#
# static uint8_t g_dtc_log_buffer[DTC_LOG_BUFFER_TOTAL_SIZE];
# static uint16_t g_current_log_pos = 0;
#
# void initDTCLoggingSystem() {
#     memset(g_dtc_log_buffer, 0, DTC_LOG_BUFFER_TOTAL_SIZE);
#     g_current_log_pos = 0;
# }
#
# int addDTCRecord(uint16_t dtc_code, uint8_t status_byte, const uint8_t* metadata, uint8_t metadata_len) {
#     if (metadata == NULL && metadata_len > 0) {
#         return -1;
#     }
#
#     if (metadata_len > MAX_DTC_METADATA_PROTO_MAX) {
#         return -2;
#     }
#
#     DTCRecord temp_record;
#     temp_record.dtc_id = dtc_code;
#     temp_record.status_byte = status_byte;
#     temp_record.metadata_len = metadata_len;
#
#     memcpy(temp_record.metadata, metadata, metadata_len);
#
#     uint16_t record_effective_size = DTC_RECORD_FIXED_SIZE + metadata_len;
#
#     if (g_current_log_pos + record_effective_size > DTC_LOG_BUFFER_TOTAL_SIZE) {
#         return -3;
#     }
#
#     memcpy(g_dtc_log_buffer + g_current_log_pos, &temp_record, record_effective_size);
#     g_current_log_pos += record_effective_size;
#
#     return 0;
# }
#
# uint16_t getDTCLogCount() {
#     if (SINGLE_DTC_RECORD_STORAGE_SIZE == 0) return 0;
#     return g_current_log_pos / SINGLE_DTC_RECORD_STORAGE_SIZE;
# }
#
# void simulateExternalDTCReport(uint16_t dtc, uint8_t status, const uint8_t* data, uint8_t data_len) {
#     addDTCRecord(dtc, status, data, data_len);
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
#
# #define MAX_DTC_METADATA_PROTO_MAX 60
# #define MAX_INTERNAL_DTC_METADATA_SIZE 30
#
# #define MAX_LOGGED_DTC_RECORDS 20
# #define DTC_RECORD_FIXED_SIZE (sizeof(uint16_t) + sizeof(uint8_t) + sizeof(uint8_t))
# #define SINGLE_DTC_RECORD_STORAGE_SIZE (DTC_RECORD_FIXED_SIZE + MAX_INTERNAL_DTC_METADATA_SIZE)
# #define DTC_LOG_BUFFER_TOTAL_SIZE (MAX_LOGGED_DTC_RECORDS * SINGLE_DTC_RECORD_STORAGE_SIZE)
#
# typedef struct {
#     uint16_t dtc_id;
#     uint8_t status_byte;
#     uint8_t metadata_len;
#     uint8_t metadata[MAX_INTERNAL_DTC_METADATA_SIZE];
# } DTCRecord;
#
# static uint8_t g_dtc_log_buffer[DTC_LOG_BUFFER_TOTAL_SIZE];
# static uint16_t g_current_log_pos = 0;
#
# void initDTCLoggingSystem() {
#     memset(g_dtc_log_buffer, 0, DTC_LOG_BUFFER_TOTAL_SIZE);
#     g_current_log_pos = 0;
# }
#
# int addDTCRecord(uint16_t dtc_code, uint8_t status_byte, const uint8_t* metadata, uint8_t metadata_len) {
#     if (metadata == NULL && metadata_len > 0) {
#         return -1;
#     }
#
#     if (metadata_len > MAX_DTC_METADATA_PROTO_MAX) {
#         return -2;
#     }
#
#     DTCRecord temp_record;
#     temp_record.dtc_id = dtc_code;
#     temp_record.status_byte = status_byte;
#
#     uint8_t actual_copy_len = metadata_len;
#     if (actual_copy_len > MAX_INTERNAL_DTC_METADATA_SIZE) {
#         actual_copy_len = MAX_INTERNAL_DTC_METADATA_SIZE;
#     }
#     temp_record.metadata_len = actual_copy_len;
#
#     memcpy(temp_record.metadata, metadata, actual_copy_len);
#
#     uint16_t record_effective_size = DTC_RECORD_FIXED_SIZE + temp_record.metadata_len;
#
#     if (g_current_log_pos + record_effective_size > DTC_LOG_BUFFER_TOTAL_SIZE) {
#         return -3;
#     }
#
#     memcpy(g_dtc_log_buffer + g_current_log_pos, &temp_record, record_effective_size);
#     g_current_log_pos += record_effective_size;
#
#     return 0;
# }
#
# uint16_t getDTCLogCount() {
#     if (SINGLE_DTC_RECORD_STORAGE_SIZE == 0) return 0;
#     return g_current_log_pos / SINGLE_DTC_RECORD_STORAGE_SIZE;
# }
#
# void simulateExternalDTCReport(uint16_t dtc, uint8_t status, const uint8_t* data, uint8_t data_len) {
#     addDTCRecord(dtc, status, data, data_len);
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <stdlib.h>
# #include <string.h>
#
# #define MAX_PACKET_SIZE 1500
# #define PARAMETER_RECORD_FIXED_HEADER_SIZE (sizeof(uint16_t) + sizeof(uint8_t))
#
# static uint8_t g_vehicleConfigMemory[512];
#
# int processVehicleConfigUpdate(const uint8_t* message_data, uint16_t message_len) {
#     if (message_data == NULL || message_len < sizeof(uint16_t)) {
#         return -1;
#     }
#
#     uint16_t num_params = (message_data[0] << 8) | message_data[1];
#     uint16_t current_read_offset = sizeof(uint16_t);
#
#     uint16_t total_payload_bytes_expected = 0;
#
#     for (uint16_t i = 0; i < num_params; ++i) {
#         if (current_read_offset + PARAMETER_RECORD_FIXED_HEADER_SIZE > message_len) {
#             return -2;
#         }
#
#         uint8_t data_len = message_data[current_read_offset + sizeof(uint16_t)];
#
#         if (current_read_offset + PARAMETER_RECORD_FIXED_HEADER_SIZE + data_len > message_len) {
#             return -3;
#         }
#
#         uint16_t param_record_size = PARAMETER_RECORD_FIXED_HEADER_SIZE + data_len;
#         total_payload_bytes_expected += param_record_size;
#
#         current_read_offset += param_record_size;
#     }
#
#     if (current_read_offset != message_len) {
#         return -4;
#     }
#
#     uint8_t* temp_stage_buffer = (uint8_t*)malloc(total_payload_bytes_expected);
#     if (temp_stage_buffer == NULL) {
#         return -5;
#     }
#
#     memcpy(temp_stage_buffer, message_data + sizeof(uint16_t), message_len - sizeof(uint16_t));
#
#     free(temp_stage_buffer);
#
#     return 0;
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <stdlib.h>
# #include <string.h>
#
# #define MAX_PACKET_SIZE 1500
# #define PARAMETER_RECORD_FIXED_HEADER_SIZE (sizeof(uint16_t) + sizeof(uint8_t))
# #define MAX_TOTAL_CONFIG_PAYLOAD_SIZE (MAX_PACKET_SIZE - sizeof(uint16_t))
#
# static uint8_t g_vehicleConfigMemory[512];
#
# int processVehicleConfigUpdate(const uint8_t* message_data, uint16_t message_len) {
#     if (message_data == NULL || message_len < sizeof(uint16_t)) {
#         return -1;
#     }
#
#     uint16_t num_params = (message_data[0] << 8) | message_data[1];
#     uint16_t current_read_offset = sizeof(uint16_t);
#
#     uint32_t total_payload_bytes_expected = 0;
#
#     for (uint16_t i = 0; i < num_params; ++i) {
#         if (current_read_offset + PARAMETER_RECORD_FIXED_HEADER_SIZE > message_len) {
#             return -2;
#         }
#
#         uint8_t data_len = message_data[current_read_offset + sizeof(uint16_t)];
#
#         if (current_read_offset + PARAMETER_RECORD_FIXED_HEADER_SIZE + data_len > message_len) {
#             return -3;
#         }
#
#         uint32_t param_record_size = (uint32_t)PARAMETER_RECORD_FIXED_HEADER_SIZE + data_len;
#
#         if (total_payload_bytes_expected > (MAX_TOTAL_CONFIG_PAYLOAD_SIZE - param_record_size)) {
#             return -6;
#         }
#         total_payload_bytes_expected += param_record_size;
#
#         current_read_offset += param_record_size;
#     }
#
#     if (current_read_offset != message_len) {
#         return -4;
#     }
#
#     if (total_payload_bytes_expected > MAX_TOTAL_CONFIG_PAYLOAD_SIZE) {
#         return -8;
#     }
#
#     uint8_t* temp_stage_buffer = (uint8_t*)malloc(total_payload_bytes_expected);
#     if (temp_stage_buffer == NULL) {
#         return -5;
#     }
#
#     memcpy(temp_stage_buffer, message_data + sizeof(uint16_t), total_payload_bytes_expected);
#
#     free(temp_stage_buffer);
#
#     return 0;
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# #define FIRMWARE_CONFIG_BUFFER_SIZE 256
# #define MAX_INCOMING_PARAM_DATA_SIZE 64
#
# static uint8_t g_firmwareConfigData[FIRMWARE_CONFIG_BUFFER_SIZE];
#
# void initFirmwareConfig() {
#     memset(g_firmwareConfigData, 0x00, FIRMWARE_CONFIG_BUFFER_SIZE);
#     g_firmwareConfigData[0] = 0xAA;
#     g_firmwareConfigData[1] = 0xBB;
# }
#
# int updateFirmwareConfigSegment(const uint8_t* packet_data, uint16_t packet_len) {
#     if (packet_data == NULL || packet_len < 2) {
#         return -1;
#     }
#
#     uint8_t config_area_offset = packet_data[0];
#     uint8_t data_segment_length = packet_data[1];
#
#     if (2 + data_segment_length > packet_len) {
#         return -2;
#     }
#
#     if (data_segment_length > MAX_INCOMING_PARAM_DATA_SIZE) {
#         return -3;
#     }
#
#     if (config_area_offset >= FIRMWARE_CONFIG_BUFFER_SIZE) {
#         return -4;
#     }
#
#     const uint8_t* actual_data_ptr = packet_data + 2;
#
#     for (uint8_t i = 0; i < data_segment_length; ++i) {
#         g_firmwareConfigData[config_area_offset + i] = actual_data_ptr[i];
#     }
#
#     return 0;
# }
#
# void handleFirmwareUpdateMessage(const uint8_t* msg_payload, uint16_t payload_size) {
#     updateFirmwareConfigSegment(msg_payload, payload_size);
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
#
# #define FIRMWARE_CONFIG_BUFFER_SIZE 256
# #define MAX_INCOMING_PARAM_DATA_SIZE 64
#
# static uint8_t g_firmwareConfigData[FIRMWARE_CONFIG_BUFFER_SIZE];
#
# void initFirmwareConfig() {
#     memset(g_firmwareConfigData, 0x00, FIRMWARE_CONFIG_BUFFER_SIZE);
#     g_firmwareConfigData[0] = 0xAA;
#     g_firmwareConfigData[1] = 0xBB;
# }
#
# int updateFirmwareConfigSegment(const uint8_t* packet_data, uint16_t packet_len) {
#     if (packet_data == NULL || packet_len < 2) {
#         return -1;
#     }
#
#     uint8_t config_area_offset = packet_data[0];
#     uint8_t data_segment_length = packet_data[1];
#
#     if (2 + data_segment_length > packet_len) {
#         return -2;
#     }
#
#     if (data_segment_length > MAX_INCOMING_PARAM_DATA_SIZE) {
#         return -3;
#     }
#
#     if (config_area_offset >= FIRMWARE_CONFIG_BUFFER_SIZE) {
#         return -4;
#     }
#
#     if (config_area_offset + data_segment_length > FIRMWARE_CONFIG_BUFFER_SIZE) {
#         return -5;
#     }
#
#     const uint8_t* actual_data_ptr = packet_data + 2;
#
#     for (uint8_t i = 0; i < data_segment_length; ++i) {
#         g_firmwareConfigData[config_area_offset + i] = actual_data_ptr[i];
#     }
#
#     return 0;
# }
#
# void handleFirmwareUpdateMessage(const uint8_t* msg_payload, uint16_t payload_size) {
#     updateFirmwareConfigSegment(msg_payload, payload_size);
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# #define AGGREGATED_DATA_BUFFER_SIZE 256
# #define MAX_INCOMING_PACKET_SIZE 512
#
# static uint8_t g_aggregatedDataBuffer[AGGREGATED_DATA_BUFFER_SIZE];
# static uint16_t g_currentAggregatedLen = 0;
#
# void initDataAggregator() {
#     memset(g_aggregatedDataBuffer, 0, AGGREGATED_DATA_BUFFER_SIZE);
#     g_currentAggregatedLen = 0;
# }
#
# typedef struct {
#     uint8_t record_type;
#     uint8_t record_length;
# } DataRecordHeader;
#
# int processDiagnosticDataPacket(const uint8_t* packet, uint16_t packet_len) {
#     if (packet == NULL || packet_len < 1) {
#         return -1;
#     }
#
#     uint16_t current_packet_offset = 0;
#     uint8_t record_count = packet[current_packet_offset++];
#
#     if (record_count == 0) {
#         g_currentAggregatedLen = 0;
#         return 0;
#     }
#     if (current_packet_offset >= packet_len) {
#         return -2;
#     }
#
#     g_currentAggregatedLen = 0;
#
#     for (int i = 0; i < record_count; ++i) {
#         if (current_packet_offset + sizeof(DataRecordHeader) > packet_len) {
#             return -3;
#         }
#
#         DataRecordHeader header;
#         header.record_type = packet[current_packet_offset];
#         current_packet_offset++;
#         header.record_length = packet[current_packet_offset];
#         current_packet_offset++;
#
#         if (current_packet_offset + header.record_length > packet_len) {
#             return -4;
#         }
#
#         for (uint8_t j = 0; j < header.record_length; ++j) {
#             g_aggregatedDataBuffer[g_currentAggregatedLen++] = packet[current_packet_offset++];
#         }
#     }
#
#     return 0;
# }
#
# void receiveDataPacket(const uint8_t* data, uint16_t len) {
#     processDiagnosticDataPacket(data, len);
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
#
# #define AGGREGATED_DATA_BUFFER_SIZE 256
# #define MAX_INCOMING_PACKET_SIZE 512
#
# static uint8_t g_aggregatedDataBuffer[AGGREGATED_DATA_BUFFER_SIZE];
# static uint16_t g_currentAggregatedLen = 0;
#
# void initDataAggregator() {
#     memset(g_aggregatedDataBuffer, 0, AGGREGATED_DATA_BUFFER_SIZE);
#     g_currentAggregatedLen = 0;
# }
#
# typedef struct {
#     uint8_t record_type;
#     uint8_t record_length;
# } DataRecordHeader;
#
# int processDiagnosticDataPacket(const uint8_t* packet, uint16_t packet_len) {
#     if (packet == NULL || packet_len < 1) {
#         return -1;
#     }
#
#     uint16_t current_packet_offset = 0;
#     uint8_t record_count = packet[current_packet_offset++];
#
#     if (record_count == 0) {
#         g_currentAggregatedLen = 0;
#         return 0;
#     }
#     if (current_packet_offset >= packet_len) {
#         return -2;
#     }
#
#     g_currentAggregatedLen = 0;
#
#     for (int i = 0; i < record_count; ++i) {
#         if (current_packet_offset + sizeof(DataRecordHeader) > packet_len) {
#             return -3;
#         }
#
#         DataRecordHeader header;
#         header.record_type = packet[current_packet_offset];
#         current_packet_offset++;
#         header.record_length = packet[current_packet_offset];
#         current_packet_offset++;
#
#         if (current_packet_offset + header.record_length > packet_len) {
#             return -4;
#         }
#
#         uint16_t bytes_to_copy_into_agg_buffer = header.record_length;
#         if (g_currentAggregatedLen + bytes_to_copy_into_agg_buffer > AGGREGATED_DATA_BUFFER_SIZE) {
#             bytes_to_copy_into_agg_buffer = AGGREGATED_DATA_BUFFER_SIZE - g_currentAggregatedLen;
#             if (bytes_to_copy_into_agg_buffer == 0) {
#                 current_packet_offset += header.record_length;
#                 continue;
#             }
#         }
#
#         for (uint8_t j = 0; j < bytes_to_copy_into_agg_buffer; ++j) {
#             g_aggregatedDataBuffer[g_currentAggregatedLen++] = packet[current_packet_offset++];
#         }
#
#         current_packet_offset += (header.record_length - bytes_to_copy_into_agg_buffer);
#
#         if (g_currentAggregatedLen == AGGREGATED_DATA_BUFFER_SIZE) {
#             return 1;
#         }
#     }
#
#     return 0;
# }
#
# void receiveDataPacket(const uint8_t* data, uint16_t len) {
#     processDiagnosticDataPacket(data, len);
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# #define EVENT_LOG_BUFFER_SIZE 256
# #define MAX_SINGLE_EVENT_PAYLOAD_SIZE 64
#
# typedef struct {
#     uint8_t event_id;
#     uint8_t payload_len;
# } EventLogHeader;
#
# static uint8_t g_eventLogBuffer[EVENT_LOG_BUFFER_SIZE];
# static uint16_t g_logWritePointer = 0;
#
# void initEventLogger() {
#     memset(g_eventLogBuffer, 0, EVENT_LOG_BUFFER_SIZE);
#     g_logWritePointer = 0;
# }
#
# int addEventToLog(uint8_t event_type, const uint8_t* event_data, uint8_t data_len) {
#     if (event_data == NULL) {
#         return -1;
#     }
#
#     if (data_len > MAX_SINGLE_EVENT_PAYLOAD_SIZE) {
#         return -2;
#     }
#
#     uint16_t entry_total_size = sizeof(EventLogHeader) + data_len;
#
#     // Vulnerability: The total size of the entry (header + data) is not checked against
#     // the remaining capacity of the global buffer before writing.
#     // An attacker can send a data_len that, while individually small (e.g., < MAX_SINGLE_EVENT_PAYLOAD_SIZE),
#     // causes an out-of-bounds write when combined with a specific g_logWritePointer value.
#     // For example, if g_logWritePointer is 250, and data_len is 8 (entry_total_size = 2+8=10),
#     // the copy will attempt to write up to index 250+2+7 = 259, overflowing the 256-byte buffer.
#
#     g_eventLogBuffer[g_logWritePointer] = event_type;
#     g_eventLogBuffer[g_logWritePointer + 1] = data_len;
#
#     // The loop iterates based on 'data_len' without an explicit bounds check for 'g_eventLogBuffer'
#     // on each iteration, relying only on previous checks that are insufficient.
#     for (uint8_t i = 0; i < data_len; ++i) {
#         g_eventLogBuffer[g_logWritePointer + 2 + i] = event_data[i];
#     }
#
#     g_logWritePointer += entry_total_size;
#
#     return 0;
# }
#
# void simulateDTCRecording(uint8_t dtc_code, const uint8_t* diagnostic_info, uint8_t info_len) {
#     if (g_logWritePointer == 0) {
#         initEventLogger();
#     }
#     addEventToLog(dtc_code, diagnostic_info, info_len);
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
#
# #define EVENT_LOG_BUFFER_SIZE 256
# #define MAX_SINGLE_EVENT_PAYLOAD_SIZE 64
#
# typedef struct {
#     uint8_t event_id;
#     uint8_t payload_len;
# } EventLogHeader;
#
# static uint8_t g_eventLogBuffer[EVENT_LOG_BUFFER_SIZE];
# static uint16_t g_logWritePointer = 0;
#
# void initEventLogger() {
#     memset(g_eventLogBuffer, 0, EVENT_LOG_BUFFER_SIZE);
#     g_logWritePointer = 0;
# }
#
# int addEventToLog(uint8_t event_type, const uint8_t* event_data, uint8_t data_len) {
#     if (event_data == NULL) {
#         return -1;
#     }
#
#     if (data_len > MAX_SINGLE_EVENT_PAYLOAD_SIZE) {
#         return -2;
#     }
#
#     uint16_t entry_total_size = sizeof(EventLogHeader) + data_len;
#
#     // FIX: Ensure the entire new entry (header + data) fits within the buffer.
#     if (g_logWritePointer + entry_total_size > EVENT_LOG_BUFFER_SIZE) {
#         return -3; // Not enough space, prevent overflow
#     }
#
#     g_eventLogBuffer[g_logWritePointer] = event_type;
#     g_eventLogBuffer[g_logWritePointer + 1] = data_len;
#
#     for (uint8_t i = 0; i < data_len; ++i) {
#         // No further bounds check needed within the loop as the aggregate check above guarantees space.
#         g_eventLogBuffer[g_logWritePointer + 2 + i] = event_data[i];
#     }
#
#     g_logWritePointer += entry_total_size;
#
#     return 0;
# }
#
# void simulateDTCRecording(uint8_t dtc_code, const uint8_t* diagnostic_info, uint8_t info_len) {
#     if (g_logWritePointer == 0) {
#         initEventLogger();
#     }
#     addEventToLog(dtc_code, diagnostic_info, info_len);
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# #define REASSEMBLY_BUFFER_SIZE 256
# #define MAX_FRAGMENT_PAYLOAD_SIZE 64
# #define FRAGMENT_HEADER_SIZE 6
#
# typedef struct {
#     uint16_t fragment_id;
#     uint16_t offset;
#     uint16_t length;
# } FragmentHeader;
#
# static uint8_t g_reassemblyBuffer[REASSEMBLY_BUFFER_SIZE];
# static uint16_t g_reassembledLength = 0;
#
# void initReassemblyBuffer() {
#     memset(g_reassemblyBuffer, 0, REASSEMBLY_BUFFER_SIZE);
#     g_reassembledLength = 0;
# }
#
# int processDataFragment(const uint8_t* raw_fragment_data, uint16_t raw_fragment_len) {
#     if (raw_fragment_data == NULL || raw_fragment_len < FRAGMENT_HEADER_SIZE) {
#         return -1;
#     }
#
#     FragmentHeader header;
#     header.fragment_id = (raw_fragment_data[0] << 8) | raw_fragment_data[1];
#     header.offset      = (raw_fragment_data[2] << 8) | raw_fragment_data[3];
#     header.length      = (raw_fragment_data[4] << 8) | raw_fragment_data[5];
#
#     if (FRAGMENT_HEADER_SIZE + header.length > raw_fragment_len) {
#         return -2;
#     }
#
#     if (header.length > MAX_FRAGMENT_PAYLOAD_SIZE) {
#         return -3;
#     }
#
#     for (uint16_t i = 0; i < header.length; ++i) {
#         g_reassemblyBuffer[header.offset + i] = raw_fragment_data[FRAGMENT_HEADER_SIZE + i];
#     }
#
#     if (header.offset + header.length > g_reassembledLength) {
#         g_reassembledLength = header.offset + header.length;
#     }
#
#     return 0;
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
#
# #define REASSEMBLY_BUFFER_SIZE 256
# #define MAX_FRAGMENT_PAYLOAD_SIZE 64
# #define FRAGMENT_HEADER_SIZE 6
#
# typedef struct {
#     uint16_t fragment_id;
#     uint16_t offset;
#     uint16_t length;
# } FragmentHeader;
#
# static uint8_t g_reassemblyBuffer[REASSEMBLY_BUFFER_SIZE];
# static uint16_t g_reassembledLength = 0;
#
# void initReassemblyBuffer() {
#     memset(g_reassemblyBuffer, 0, REASSEMBLY_BUFFER_SIZE);
#     g_reassembledLength = 0;
# }
#
# int processDataFragment(const uint8_t* raw_fragment_data, uint16_t raw_fragment_len) {
#     if (raw_fragment_data == NULL || raw_fragment_len < FRAGMENT_HEADER_SIZE) {
#         return -1;
#     }
#
#     FragmentHeader header;
#     header.fragment_id = (raw_fragment_data[0] << 8) | raw_fragment_data[1];
#     header.offset      = (raw_fragment_data[2] << 8) | raw_fragment_data[3];
#     header.length      = (raw_fragment_data[4] << 8) | raw_fragment_data[5];
#
#     if (FRAGMENT_HEADER_SIZE + header.length > raw_fragment_len) {
#         return -2;
#     }
#
#     if (header.length > MAX_FRAGMENT_PAYLOAD_SIZE) {
#         return -3;
#     }
#
#     if (header.offset >= REASSEMBLY_BUFFER_SIZE || (header.length > 0 && header.offset + header.length > REASSEMBLY_BUFFER_SIZE)) {
#         return -4;
#     }
#
#     for (uint16_t i = 0; i < header.length; ++i) {
#         g_reassemblyBuffer[header.offset + i] = raw_fragment_data[FRAGMENT_HEADER_SIZE + i];
#     }
#
#     if (header.offset + header.length > g_reassembledLength) {
#         g_reassembledLength = header.offset + header.length;
#     }
#
#     return 0;
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
# #include <stdbool.h>
#
# #define CALIBRATION_BLOCK_SIZE 64
# #define NUM_CALIBRATION_BLOCKS 8
# #define TOTAL_CALIBRATION_SIZE (CALIBRATION_BLOCK_SIZE * NUM_CALIBRATION_BLOCKS)
#
# static uint8_t g_calibrationData[TOTAL_CALIBRATION_SIZE];
# static bool g_calibrationInitialized = false;
#
# void initCalibrationSystem() {
#     memset(g_calibrationData, 0, TOTAL_CALIBRATION_SIZE);
#     g_calibrationInitialized = true;
# }
#
# int processCalibrationFragment(const uint8_t* msg_payload, uint16_t payload_len) {
#     if (!g_calibrationInitialized || msg_payload == NULL || payload_len < 5) {
#         return -1;
#     }
#
#     uint8_t block_idx = msg_payload[0];
#     uint16_t block_offset = (msg_payload[1] << 8) | msg_payload[2];
#     uint16_t data_len = (msg_payload[3] << 8) | msg_payload[4];
#
#     if (payload_len < (5 + data_len)) {
#         return -2;
#     }
#
#     if (block_idx >= NUM_CALIBRATION_BLOCKS) {
#         return -3;
#     }
#
#     if (block_offset >= CALIBRATION_BLOCK_SIZE) {
#         return -4;
#     }
#
#     const uint8_t* data_payload = msg_payload + 5;
#
#     uint16_t global_start_offset = (uint16_t)block_idx * CALIBRATION_BLOCK_SIZE + block_offset;
#
#     for (uint16_t i = 0; i < data_len; ++i) {
#         g_calibrationData[global_start_offset + i] = data_payload[i];
#     }
#
#     return 0;
# }
#
# void handleCANCalibrationMessage(const uint8_t* can_data, uint16_t can_dlc) {
#     processCalibrationFragment(can_data, can_dlc);
# }
#
# uint8_t getCalibrationByte(uint16_t index) {
#     if (index < TOTAL_CALIBRATION_SIZE) {
#         return g_calibrationData[index];
#     }
#     return 0xFF;
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
# #include <stdbool.h>
#
# #define CALIBRATION_BLOCK_SIZE 64
# #define NUM_CALIBRATION_BLOCKS 8
# #define TOTAL_CALIBRATION_SIZE (CALIBRATION_BLOCK_SIZE * NUM_CALIBRATION_BLOCKS)
#
# static uint8_t g_calibrationData[TOTAL_CALIBRATION_SIZE];
# static bool g_calibrationInitialized = false;
#
# void initCalibrationSystem() {
#     memset(g_calibrationData, 0, TOTAL_CALIBRATION_SIZE);
#     g_calibrationInitialized = true;
# }
#
# int processCalibrationFragment(const uint8_t* msg_payload, uint16_t payload_len) {
#     if (!g_calibrationInitialized || msg_payload == NULL || payload_len < 5) {
#         return -1;
#     }
#
#     uint8_t block_idx = msg_payload[0];
#     uint16_t block_offset = (msg_payload[1] << 8) | msg_payload[2];
#     uint16_t data_len = (msg_payload[3] << 8) | msg_payload[4];
#
#     if (payload_len < (5 + data_len)) {
#         return -2;
#     }
#
#     if (block_idx >= NUM_CALIBRATION_BLOCKS) {
#         return -3;
#     }
#
#     const uint8_t* data_payload = msg_payload + 5;
#
#     uint16_t global_start_offset = (uint16_t)block_idx * CALIBRATION_BLOCK_SIZE + block_offset;
#
#     if (global_start_offset >= TOTAL_CALIBRATION_SIZE ||
#         global_start_offset + data_len > TOTAL_CALIBRATION_SIZE) {
#         return -5;
#     }
#
#     for (uint16_t i = 0; i < data_len; ++i) {
#         g_calibrationData[global_start_offset + i] = data_payload[i];
#     }
#
#     return 0;
# }
#
# void handleCANCalibrationMessage(const uint8_t* can_data, uint16_t can_dlc) {
#     processCalibrationFragment(can_data, can_dlc);
# }
#
# uint8_t getCalibrationByte(uint16_t index) {
#     if (index < TOTAL_CALIBRATION_SIZE) {
#         return g_calibrationData[index];
#     }
#     return 0xFF;
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
# #include <stdbool.h>
#
# #define MAX_CAN_FRAME_DATA_LENGTH 8
# #define VEHICLE_STATE_SENSOR_ID 0x01
# #define TIRE_PRESSURE_SENSOR_ID 0x02
# #define FUEL_LEVEL_SENSOR_ID 0x03
# #define VEHICLE_DIAGNOSTIC_DATA_ID 0x04
#
# #define MAX_SENSOR_DATA_PAYLOAD 60
#
# #define DIAGNOSTIC_STRING_BUFFER_SIZE 30
#
# typedef struct {
#     uint8_t sensor_id;
#     uint8_t data_length;
#     uint8_t data[MAX_SENSOR_DATA_PAYLOAD];
# } SensorPacketSegment;
#
# int processSensorTelemetryStream(const uint8_t* msg_buffer, uint16_t msg_len) {
#     if (msg_buffer == NULL || msg_len < (sizeof(uint8_t) * 2)) {
#         return -1;
#     }
#
#     uint16_t current_offset = 0;
#
#     while (current_offset < msg_len) {
#         if (current_offset + sizeof(uint8_t) * 2 > msg_len) {
#             return -2;
#         }
#
#         uint8_t sensor_id = msg_buffer[current_offset];
#         uint8_t data_len = msg_buffer[current_offset + 1];
#
#         if (current_offset + sizeof(uint8_t) * 2 + data_len > msg_len) {
#             return -3;
#         }
#
#         const uint8_t* sensor_data_ptr = msg_buffer + current_offset + sizeof(uint8_t) * 2;
#
#         if (sensor_id == VEHICLE_DIAGNOSTIC_DATA_ID) {
#             char diagnostic_buffer[DIAGNOSTIC_STRING_BUFFER_SIZE];
#             memset(diagnostic_buffer, 0, DIAGNOSTIC_STRING_BUFFER_SIZE);
#
#             for (int i = 0; i < data_len; ++i) {
#                 diagnostic_buffer[i] = (char)sensor_data_ptr[i];
#             }
#             diagnostic_buffer[data_len] = '\0';
#
#         }
#
#         current_offset += (sizeof(uint8_t) * 2 + data_len);
#     }
#
#     return 0;
# }
#
# void handleTelemetryStream(const uint8_t* stream, uint16_t len) {
#     processSensorTelemetryStream(stream, len);
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
# #include <stdbool.h>
#
# #define MAX_CAN_FRAME_DATA_LENGTH 8
# #define VEHICLE_STATE_SENSOR_ID 0x01
# #define TIRE_PRESSURE_SENSOR_ID 0x02
# #define FUEL_LEVEL_SENSOR_ID 0x03
# #define VEHICLE_DIAGNOSTIC_DATA_ID 0x04
#
# #define MAX_SENSOR_DATA_PAYLOAD 60
#
# #define DIAGNOSTIC_STRING_BUFFER_SIZE 30
#
# typedef struct {
#     uint8_t sensor_id;
#     uint8_t data_length;
#     uint8_t data[MAX_SENSOR_DATA_PAYLOAD];
# } SensorPacketSegment;
#
# int processSensorTelemetryStream(const uint8_t* msg_buffer, uint16_t msg_len) {
#     if (msg_buffer == NULL || msg_len < (sizeof(uint8_t) * 2)) {
#         return -1;
#     }
#
#     uint16_t current_offset = 0;
#
#     while (current_offset < msg_len) {
#         if (current_offset + sizeof(uint8_t) * 2 > msg_len) {
#             return -2;
#         }
#
#         uint8_t sensor_id = msg_buffer[current_offset];
#         uint8_t data_len = msg_buffer[current_offset + 1];
#
#         if (current_offset + sizeof(uint8_t) * 2 + data_len > msg_len) {
#             return -3;
#         }
#
#         const uint8_t* sensor_data_ptr = msg_buffer + current_offset + sizeof(uint8_t) * 2;
#
#         if (sensor_id == VEHICLE_DIAGNOSTIC_DATA_ID) {
#             char diagnostic_buffer[DIAGNOSTIC_STRING_BUFFER_SIZE];
#             memset(diagnostic_buffer, 0, DIAGNOSTIC_STRING_BUFFER_SIZE);
#
#             uint8_t bytes_to_copy = data_len;
#             if (bytes_to_copy >= DIAGNOSTIC_STRING_BUFFER_SIZE) {
#                 bytes_to_copy = DIAGNOSTIC_STRING_BUFFER_SIZE - 1;
#             }
#
#             for (int i = 0; i < bytes_to_copy; ++i) {
#                 diagnostic_buffer[i] = (char)sensor_data_ptr[i];
#             }
#             diagnostic_buffer[bytes_to_copy] = '\0';
#
#         }
#
#         current_offset += (sizeof(uint8_t) * 2 + data_len);
#     }
#
#     return 0;
# }
#
# void handleTelemetryStream(const uint8_t* stream, uint16_t len) {
#     processSensorTelemetryStream(stream, len);
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# #define CRITICAL_CALIBRATION_VALUES_COUNT 10
# #define CALIBRATION_BUFFER_SIZE (CRITICAL_CALIBRATION_VALUES_COUNT * sizeof(uint16_t))
#
# static uint16_t g_criticalCalibrationValues[CRITICAL_CALIBRATION_VALUES_COUNT];
#
# void initCalibrationValues() {
#     memset(g_criticalCalibrationValues, 0, CALIBRATION_BUFFER_SIZE);
#     for (uint8_t i = 0; i < CRITICAL_CALIBRATION_VALUES_COUNT; ++i) {
#         g_criticalCalibrationValues[i] = (i + 1) * 100;
#     }
# }
#
# typedef struct {
#     uint8_t  group_id;
#     uint8_t  item_offset;
#     uint16_t new_value;
# } CalibrationUpdateCommand;
#
# int applyCalibrationUpdate(const CalibrationUpdateCommand* command) {
#     if (command == NULL) {
#         return -1;
#     }
#
#     uint8_t group_id = command->group_id;
#     uint8_t item_offset = command->item_offset;
#     uint16_t new_value = command->new_value;
#
#     uint8_t effective_index_base_8bit;
#
#     switch (group_id) {
#         case 0:
#             effective_index_base_8bit = 0;
#             break;
#         case 1:
#             effective_index_base_8bit = 5;
#             break;
#         case 2:
#             effective_index_base_8bit = 250;
#             break;
#         default:
#             return -2;
#     }
#
#     uint8_t final_index_8bit = effective_index_base_8bit + item_offset;
#
#     if (final_index_8bit >= CRITICAL_CALIBRATION_VALUES_COUNT) {
#         return -3;
#     }
#
#     g_criticalCalibrationValues[final_index_8bit] = new_value;
#
#     return 0;
# }
#
# void simulateExternalCalibrationUpdate(uint8_t group, uint8_t offset, uint16_t value) {
#     CalibrationUpdateCommand cmd = { .group_id = group, .item_offset = offset, .new_value = value };
#     applyCalibrationUpdate(&cmd);
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
#
# #define CRITICAL_CALIBRATION_VALUES_COUNT 10
# #define CALIBRATION_BUFFER_SIZE (CRITICAL_CALIBRATION_VALUES_COUNT * sizeof(uint16_t))
#
# static uint16_t g_criticalCalibrationValues[CRITICAL_CALIBRATION_VALUES_COUNT];
#
# void initCalibrationValues() {
#     memset(g_criticalCalibrationValues, 0, CALIBRATION_BUFFER_SIZE);
#     for (uint8_t i = 0; i < CRITICAL_CALIBRATION_VALUES_COUNT; ++i) {
#         g_criticalCalibrationValues[i] = (i + 1) * 100;
#     }
# }
#
# typedef struct {
#     uint8_t  group_id;
#     uint8_t  item_offset;
#     uint16_t new_value;
# } CalibrationUpdateCommand;
#
# int applyCalibrationUpdate(const CalibrationUpdateCommand* command) {
#     if (command == NULL) {
#         return -1;
#     }
#
#     uint8_t group_id = command->group_id;
#     uint8_t item_offset = command->item_offset;
#     uint16_t new_value = command->new_value;
#
#     uint16_t effective_index_base;
#
#     switch (group_id) {
#         case 0:
#             effective_index_base = 0;
#             break;
#         case 1:
#             effective_index_base = 5;
#             break;
#         case 2:
#             effective_index_base = 250;
#             break;
#         default:
#             return -2;
#     }
#
#     uint16_t final_index = effective_index_base + item_offset;
#
#     if (final_index >= CRITICAL_CALIBRATION_VALUES_COUNT) {
#         return -3;
#     }
#
#     g_criticalCalibrationValues[final_index] = new_value;
#
#     return 0;
# }
#
# void simulateExternalCalibrationUpdate(uint8_t group, uint8_t offset, uint16_t value) {
#     CalibrationUpdateCommand cmd = { .group_id = group, .item_offset = offset, .new_value = value };
#     applyCalibrationUpdate(&cmd);
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# // Define CAN message IDs for specific diagnostic services
# #define CAN_ID_CONFIG_UPDATE_SERVICE 0x18F00100
# #define CAN_ID_STATUS_REQUEST_SERVICE 0x18F00200
#
# // Maximum number of configurable parameters
# #define MAX_CONFIG_PARAMETERS 64
#
# // Structure for a single configurable parameter entry
# typedef struct {
#     uint8_t id;
#     uint8_t value;
#     uint8_t type;
# } ConfigParameterEntry;
#
# // Main ECU configuration storage
# static ConfigParameterEntry ecu_config_store[MAX_CONFIG_PARAMETERS];
#
# // Initializes the ECU configuration store with default values
# void init_ecu_config_store() {
#     for (int i = 0; i < MAX_CONFIG_PARAMETERS; ++i) {
#         ecu_config_store[i].id = (uint8_t)i;
#         ecu_config_store[i].value = 0x00;
#         ecu_config_store[i].type = 0x00;
#     }
# }
#
# // Function to process a CAN diagnostic message payload
# // This function assumes the msg_id has already been validated to be a config update service.
# // The payload format for config update: [param_index_byte][param_value_byte]
# // This service allows setting a single parameter at a time.
# int process_config_update_payload(const uint8_t* payload, uint8_t payload_len) {
#     if (payload == NULL || payload_len < 2) {
#         return -1;
#     }
#
#     uint8_t param_idx_received = payload[0];
#     uint8_t new_param_value = payload[1];
#
#     // The vulnerability: No bounds check on param_idx_received.
#     // An attacker can send param_idx_received >= MAX_CONFIG_PARAMETERS
#     // to write to memory outside ecu_config_store.
#     ecu_config_store[param_idx_received].value = new_param_value;
#
#     return 0;
# }
#
# // Main entry point for processing incoming CAN messages
# // This function would typically be called by a CAN driver interrupt or polling loop.
# int handle_can_diagnostic_message(uint32_t can_id, const uint8_t* data_bytes, uint8_t data_len) {
#     if (data_bytes == NULL || data_len == 0) {
#         return -1;
#     }
#
#     switch (can_id) {
#         case CAN_ID_CONFIG_UPDATE_SERVICE:
#             return process_config_update_payload(data_bytes, data_len);
#         case CAN_ID_STATUS_REQUEST_SERVICE:
#             // Placeholder for status request handling logic
#             return 0;
#         default:
#             return -99;
#     }
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
#
# // Define CAN message IDs for specific diagnostic services
# #define CAN_ID_CONFIG_UPDATE_SERVICE 0x18F00100
# #define CAN_ID_STATUS_REQUEST_SERVICE 0x18F00200
#
# // Maximum number of configurable parameters
# #define MAX_CONFIG_PARAMETERS 64
#
# // Structure for a single configurable parameter entry
# typedef struct {
#     uint8_t id;
#     uint8_t value;
#     uint8_t type;
# } ConfigParameterEntry;
#
# // Main ECU configuration storage
# static ConfigParameterEntry ecu_config_store[MAX_CONFIG_PARAMETERS];
#
# // Initializes the ECU configuration store with default values
# void init_ecu_config_store() {
#     for (int i = 0; i < MAX_CONFIG_PARAMETERS; ++i) {
#         ecu_config_store[i].id = (uint8_t)i;
#         ecu_config_store[i].value = 0x00;
#         ecu_config_store[i].type = 0x00;
#     }
# }
#
# // Function to process a CAN diagnostic message payload
# // This function assumes the msg_id has already been validated to be a config update service.
# // The payload format for config update: [param_index_byte][param_value_byte]
# // This service allows setting a single parameter at a time.
# int process_config_update_payload(const uint8_t* payload, uint8_t payload_len) {
#     if (payload == NULL || payload_len < 2) {
#         return -1;
#     }
#
#     uint8_t param_idx_received = payload[0];
#     uint8_t new_param_value = payload[1];
#
#     // The fix: Add a bounds check for param_idx_received
#     if (param_idx_received >= MAX_CONFIG_PARAMETERS) {
#         return -2;
#     }
#
#     ecu_config_store[param_idx_received].value = new_param_value;
#
#     return 0;
# }
#
# // Main entry point for processing incoming CAN messages
# // This function would typically be called by a CAN driver interrupt or polling loop.
# int handle_can_diagnostic_message(uint32_t can_id, const uint8_t* data_bytes, uint8_t data_len) {
#     if (data_bytes == NULL || data_len == 0) {
#         return -1;
#     }
#
#     switch (can_id) {
#         case CAN_ID_CONFIG_UPDATE_SERVICE:
#             return process_config_update_payload(data_bytes, data_len);
#         case CAN_ID_STATUS_REQUEST_SERVICE:
#             // Placeholder for status request handling logic
#             return 0;
#         default:
#             return -99;
#     }
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# #define NUM_SENSOR_PROFILES 4
# #define SENSOR_PROFILE_BUFFER_SIZE 64
# #define MAX_CALIBRATION_PAYLOAD_SIZE 32
#
# static uint8_t g_sensorCalibrationProfiles[NUM_SENSOR_PROFILES][SENSOR_PROFILE_BUFFER_SIZE];
#
# void initSensorCalibrationProfiles() {
#     for (int i = 0; i < NUM_SENSOR_PROFILES; ++i) {
#         memset(g_sensorCalibrationProfiles[i], 0x00, SENSOR_PROFILE_BUFFER_SIZE);
#         g_sensorCalibrationProfiles[i][0] = i;
#     }
# }
#
# typedef struct {
#     uint8_t  profile_index;
#     uint8_t  data_offset;
#     uint8_t  data_length;
#     uint8_t  payload[MAX_CALIBRATION_PAYLOAD_SIZE];
# } SensorCalibrationUpdateMsg;
#
# int applyCalibrationUpdate(const SensorCalibrationUpdateMsg* msg) {
#     if (msg == NULL) {
#         return -1;
#     }
#
#     uint8_t profile_idx = msg->profile_index;
#     uint8_t offset = msg->data_offset;
#     uint8_t length = msg->data_length;
#     const uint8_t* data = msg->payload;
#
#     if (profile_idx >= NUM_SENSOR_PROFILES) {
#         return -2;
#     }
#
#     if (length == 0 || length > MAX_CALIBRATION_PAYLOAD_SIZE) {
#         return -3;
#     }
#
#     if (offset >= SENSOR_PROFILE_BUFFER_SIZE) {
#         return -4;
#     }
#
#     for (uint8_t i = 0; i < length; ++i) {
#         g_sensorCalibrationProfiles[profile_idx][offset + i] = data[i];
#     }
#
#     return 0;
# }
#
# void simulateCalibrationMessage(uint8_t p_idx, uint8_t off, uint8_t len, const uint8_t* payload_data) {
#     SensorCalibrationUpdateMsg msg;
#     msg.profile_index = p_idx;
#     msg.data_offset = off;
#     msg.data_length = len;
#     if (len > MAX_CALIBRATION_PAYLOAD_SIZE) {
#         len = MAX_CALIBRATION_PAYLOAD_SIZE;
#     }
#     for (uint8_t i = 0; i < len; ++i) {
#         msg.payload[i] = payload_data[i];
#     }
#     applyCalibrationUpdate(&msg);
# }
#
# uint8_t getCalibrationByte(uint8_t profile_idx, uint8_t offset) {
#     if (profile_idx < NUM_SENSOR_PROFILES && offset < SENSOR_PROFILE_BUFFER_SIZE) {
#         return g_sensorCalibrationProfiles[profile_idx][offset];
#     }
#     return 0xFF;
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
#
# #define NUM_SENSOR_PROFILES 4
# #define SENSOR_PROFILE_BUFFER_SIZE 64
# #define MAX_CALIBRATION_PAYLOAD_SIZE 32
#
# static uint8_t g_sensorCalibrationProfiles[NUM_SENSOR_PROFILES][SENSOR_PROFILE_BUFFER_SIZE];
#
# void initSensorCalibrationProfiles() {
#     for (int i = 0; i < NUM_SENSOR_PROFILES; ++i) {
#         memset(g_sensorCalibrationProfiles[i], 0x00, SENSOR_PROFILE_BUFFER_SIZE);
#         g_sensorCalibrationProfiles[i][0] = i;
#     }
# }
#
# typedef struct {
#     uint8_t  profile_index;
#     uint8_t  data_offset;
#     uint8_t  data_length;
#     uint8_t  payload[MAX_CALIBRATION_PAYLOAD_SIZE];
# } SensorCalibrationUpdateMsg;
#
# int applyCalibrationUpdate(const SensorCalibrationUpdateMsg* msg) {
#     if (msg == NULL) {
#         return -1;
#     }
#
#     uint8_t profile_idx = msg->profile_index;
#     uint8_t offset = msg->data_offset;
#     uint8_t length = msg->data_length;
#     const uint8_t* data = msg->payload;
#
#     if (profile_idx >= NUM_SENSOR_PROFILES) {
#         return -2;
#     }
#
#     if (length == 0 || length > MAX_CALIBRATION_PAYLOAD_SIZE) {
#         return -3;
#     }
#
#     if (offset >= SENSOR_PROFILE_BUFFER_SIZE) {
#         return -4;
#     }
#
#     if ((uint16_t)offset + length > SENSOR_PROFILE_BUFFER_SIZE) {
#         return -5;
#     }
#
#     for (uint8_t i = 0; i < length; ++i) {
#         g_sensorCalibrationProfiles[profile_idx][offset + i] = data[i];
#     }
#
#     return 0;
# }
#
# void simulateCalibrationMessage(uint8_t p_idx, uint8_t off, uint8_t len, const uint8_t* payload_data) {
#     SensorCalibrationUpdateMsg msg;
#     msg.profile_index = p_idx;
#     msg.data_offset = off;
#     msg.data_length = len;
#     if (len > MAX_CALIBRATION_PAYLOAD_SIZE) {
#         len = MAX_CALIBRATION_PAYLOAD_SIZE;
#     }
#     for (uint8_t i = 0; i < len; ++i) {
#         msg.payload[i] = payload_data[i];
#     }
#     applyCalibrationUpdate(&msg);
# }
#
# uint8_t getCalibrationByte(uint8_t profile_idx, uint8_t offset) {
#     if (profile_idx < NUM_SENSOR_PROFILES && offset < SENSOR_PROFILE_BUFFER_SIZE) {
#         return g_sensorCalibrationProfiles[profile_idx][offset];
#     }
#     return 0xFF;
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# #define NUM_VEHICLE_COMPONENTS 10
# #define BASE_INTERVAL_ARRAY_SIZE NUM_VEHICLE_COMPONENTS
# #define PROFILE_MODIFIER_ARRAY_SIZE (NUM_VEHICLE_COMPONENTS * 2)
#
# static uint16_t g_componentBaseIntervals[BASE_INTERVAL_ARRAY_SIZE];
# static int16_t g_componentProfileModifiers[PROFILE_MODIFIER_ARRAY_SIZE];
#
# typedef struct {
#     uint8_t component_idx;
#     uint8_t profile_offset;
#     int8_t adjustment_value;
# } MaintenanceUpdateReq;
#
# void initMaintenanceSystem() {
#     memset(g_componentBaseIntervals, 0, sizeof(g_componentBaseIntervals));
#     memset(g_componentProfileModifiers, 0, sizeof(g_componentProfileModifiers));
#     for (uint8_t i = 0; i < NUM_VEHICLE_COMPONENTS; ++i) {
#         g_componentBaseIntervals[i] = 1000 + (i * 10);
#         g_componentProfileModifiers[i * 2] = 0;
#         g_componentProfileModifiers[i * 2 + 1] = -50;
#     }
# }
#
# int applyMaintenanceScheduleUpdate(const MaintenanceUpdateReq* req) {
#     if (req == NULL) {
#         return -1;
#     }
#
#     if (req->component_idx >= NUM_VEHICLE_COMPONENTS) {
#         return -2;
#     }
#
#     uint16_t effective_modifier_index = (uint16_t)(req->component_idx * 2) + req->profile_offset;
#
#     g_componentProfileModifiers[effective_modifier_index] += req->adjustment_value;
#
#     g_componentBaseIntervals[req->component_idx] += (req->adjustment_value / 2);
#
#     return 0;
# }
#
# void simulateMaintenanceRequest(uint8_t comp_id, uint8_t profile_off, int8_t adj_val) {
#     MaintenanceUpdateReq request = { .component_idx = comp_id, .profile_offset = profile_off, .adjustment_value = adj_val };
#     applyMaintenanceScheduleUpdate(&request);
# }
#
# Fixed Code:
# #include <stdint.h>
# #include <string.h>
#
# #define NUM_VEHICLE_COMPONENTS 10
# #define BASE_INTERVAL_ARRAY_SIZE NUM_VEHICLE_COMPONENTS
# #define PROFILE_MODIFIER_ARRAY_SIZE (NUM_VEHICLE_COMPONENTS * 2)
#
# static uint16_t g_componentBaseIntervals[BASE_INTERVAL_ARRAY_SIZE];
# static int16_t g_componentProfileModifiers[PROFILE_MODIFIER_ARRAY_SIZE];
#
# typedef struct {
#     uint8_t component_idx;
#     uint8_t profile_offset;
#     int8_t adjustment_value;
# } MaintenanceUpdateReq;
#
# void initMaintenanceSystem() {
#     memset(g_componentBaseIntervals, 0, sizeof(g_componentBaseIntervals));
#     memset(g_componentProfileModifiers, 0, sizeof(g_componentProfileModifiers));
#     for (uint8_t i = 0; i < NUM_VEHICLE_COMPONENTS; ++i) {
#         g_componentBaseIntervals[i] = 1000 + (i * 10);
#         g_componentProfileModifiers[i * 2] = 0;
#         g_componentProfileModifiers[i * 2 + 1] = -50;
#     }
# }
#
# int applyMaintenanceScheduleUpdate(const MaintenanceUpdateReq* req) {
#     if (req == NULL) {
#         return -1;
#     }
#
#     if (req->component_idx >= NUM_VEHICLE_COMPONENTS) {
#         return -2;
#     }
#
#     uint16_t effective_modifier_index = (uint16_t)(req->component_idx * 2) + req->profile_offset;
#
#     if (effective_modifier_index >= PROFILE_MODIFIER_ARRAY_SIZE) {
#         return -3;
#     }
#
#     g_componentProfileModifiers[effective_modifier_index] += req->adjustment_value;
#
#     g_componentBaseIntervals[req->component_idx] += (req->adjustment_value / 2);
#
#     return 0;
# }
#
# void simulateMaintenanceRequest(uint8_t comp_id, uint8_t profile_off, int8_t adj_val) {
#     MaintenanceUpdateReq request = { .component_idx = comp_id, .profile_offset = profile_off, .adjustment_value = adj_val };
#     applyMaintenanceScheduleUpdate(&request);
# }
#
# ==================================================
#
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <stdint.h>
# #include <string.h>
#
# #define MAX_ENGINE_CALIBRATION_POINTS 100
# #define MAX_PAYLOAD_FOR_CALIBRATION 512
#
# typedef struct {
#     uint16_t rpm_target;
#     uint16_t fuel_injection_pulse;
# } EngineCalibrationPoint;
#
# ...
# #include <stdbool.h>
# #include <string.h>
#
# #define PARAM_NAME_MAX_LEN          16
# #define PARAM_VALUE_BUFFER_SIZE     32
#
# #define PROTOCOL_MAX_VALUE_LEN      60
#
# typedef enum {
#     PARAM_TYPE_UINT8,
#     PARAM_TYPE_UINT16,
#     PARAM_TYPE_STRING,
#     PARAM_TYPE_BYTE_ARRAY
# } ParameterType;
#
# typedef struct {
#     char name[PARAM_NAME_MAX_LEN];
#     ParameterType type;
#     uint8_t value_len;
#     union {
#         uint8_t  u8_val;
#         uint16_t u16_val;
#         char     str_val[PARAM_VALUE_BUFFER_SIZE];
#         uint8_t  byte_array_val[PARAM_VALUE_BUFFER_SIZE];
#     } value;
# } VehicleParameter;
#
# static uint8_t g_message_rx_buffer[256];
#
# static uint8_t get_byte_from_stream(const uint8_t* stream_data, uint32_t* offset, uint32_t total_length) {
#     if (stream_data == NULL || *offset >= total_length) {
#         return 0;
#     }
#     return stream_data[(*offset)++];
# }
#
# int parseVehicleParameter(const uint8_t* raw_message_stream, uint32_t stream_total_len, VehicleParameter* param_out) {
#     uint32_t current_stream_pos = 0;
#
#     if (raw_message_stream == NULL || param_out == NULL || stream_total_len < (1 + 1 + 1)) {
#         return -1;
#     }
#
#     memset(param_out, 0, sizeof(VehicleParameter));
#
#     if (current_stream_pos + 1 > stream_total_len) return -2;
#     uint8_t name_len = get_byte_from_stream(raw_message_stream, &current_stream_pos, stream_total_len);
#
#     if (name_len == 0 || name_len >= PARAM_NAME_MAX_LEN) {
#         return -3;
#     }
#
#     if (current_stream_pos + name_len > stream_total_len) {
#         return -4;
#     }
#     for (int i = 0; i < name_len; ++i) {
#         param_out->name[i] = get_byte_from_stream(raw_message_stream, &current_stream_pos, stream_total_len);
#     }
#     param_out->name[name_len] = '\0';
#
#     if (current_stream_pos + 1 > stream_total_len) return -5;
#     param_out->type = (ParameterType)get_byte_from_stream(raw_message_stream, &current_stream_pos, stream_total_len);
#
#     switch (param_out->type) {
#         case PARAM_TYPE_UINT8:
#             if (current_stream_pos + sizeof(uint8_t) > stream_total_len) return -6;
#             param_out->value.u8_val = get_byte_from_stream(raw_message_stream, &current_stream_pos, stream_total_len);
#             param_out->value_len = sizeof(uint8_t);
#             break;
#         case PARAM_TYPE_UINT16:
#             if (current_stream_pos + sizeof(uint16_t) > stream_total_len) return -6;
#             param_out->value.u16_val = (uint16_t)((get_byte_from_stream(raw_message_stream, &current_stream_pos, stream_total_len) << 8) |
#                                                    get_byte_from_stream(raw_message_stream, &current_stream_pos, stream_total_len));
#             param_out->value_len = sizeof(uint16_t);
#             break;
#         case PARAM_TYPE_STRING:
#         case PARAM_TYPE_BYTE_ARRAY:
#             if (current_stream_pos + 1 > stream_total_len) return -6;
#             uint8_t declared_value_len = get_byte_from_stream(raw_message_stream, &current_stream_pos, stream_total_len);
#
#             if (declared_value_len > PROTOCOL_MAX_VALUE_LEN) {
#                 return -7;
#             }
#
#             if (current_stream_pos + declared_value_len > stream_total_len) {
#                 return -8;
#             }
#
#             uint8_t bytes_to_copy = declared_value_len;
#             if (bytes_to_copy > PARAM_VALUE_BUFFER_SIZE) {
#                 bytes_to_copy = PARAM_VALUE_BUFFER_SIZE;
#             }
#             param_out->value_len = bytes_to_copy;
#
#             for (int i = 0; i < bytes_to_copy; ++i) {
#                 if (param_out->type == PARAM_TYPE_STRING) {
#                     param_out->value.str_val[i] = get_byte_from_stream(raw_message_stream, &current_stream_pos, stream_total_len);
#                 } else {
#                     param_out->value.byte_array_val[i] = get_byte_from_stream(raw_message_stream, &current_stream_pos, stream_total_len);
#                 }
#             }
#             for (int i = bytes_to_copy; i < declared_value_len; ++i) {
#                 get_byte_from_stream(raw_message_stream, &current_stream_pos, stream_total_len);
#             }
#
#             if (param_out->type == PARAM_TYPE_STRING) {
#                 if (bytes_to_copy < PARAM_VALUE_BUFFER_SIZE) {
#                     param_out->value.str_val[bytes_to_copy] = '\0';
#                 } else {
#                     param_out->value.str_val[PARAM_VALUE_BUFFER_SIZE - 1] = '\0';
#                     param_out->value_len = PARAM_VALUE_BUFFER_SIZE - 1;
#                 }
#             }
#             break;
#         default:
#             return -9;
#     }
#
#     return current_stream_pos;
# }
#
# void simulateConfigUpdate() {
#     uint8_t malicious_message_data[51];
#     memset(malicious_message_data, 0, sizeof(malicious_message_data));
#
#     uint32_t offset = 0;
#     malicious_message_data[offset++] = strlen("SensorSetting");
#     memcpy(malicious_message_data + offset, "SensorSetting", strlen("SensorSetting"));
#     offset += strlen("SensorSetting");
#     malicious_message_data[offset++] = PARAM_TYPE_STRING;
#     malicious_message_data[offset++] = 35;
#     for (int i = 0; i < 35; ++i) {
#         malicious_message_data[offset++] = 'A';
#     }
#
#     VehicleParameter param;
#     (void)parseVehicleParameter(malicious_message_data, sizeof(malicious_message_data), &param);
# }
#
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 17
#      14     examples.append({'vulnerable_code': item['vulnerable_code'], 'fixed_code': item['fixed_code']})
#      16 for i in range(100 - len(examples)):
# ---> 17     pair = get_code_pair(cwe_id, random.choices(examples, k=8) if examples else None)
#      18     if pair:
#      19         examples.append({'vulnerable_code': pair.vulnerable_code, 'fixed_code': pair.fixed_code})
#
# Cell In[61], line 47, in get_code_pair(cwe_id, examples)
#      45 def get_code_pair(cwe_id: str, examples: dict | None = None) -> CodePairResponse:
#      46     try:
# ---> 47         response = client.models.generate_content(
#      48             model="gemini-2.5-flash-preview-05-20",
#      49             contents=generate_prompt(cwe_id, examples),
#      50             config={
#      51                 "response_mime_type": "application/json",
#      52                 "response_schema": CodePairResponse,
#      53             },
#      54         )
#      55         # if server error, return empty list
#      56     except genai.errors.ServerError as e:
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/google/genai/models.py:5977, in Models.generate_content(self, model, contents, config)
#    5975 while remaining_remote_calls_afc > 0:
#    5976   i += 1
# -> 5977   response = self._generate_content(
#    5978       model=model, contents=contents, config=parsed_config
#    5979   )
#    5980   logger.info(f'AFC remote call {i} is done.')
#    5981   remaining_remote_calls_afc -= 1
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/google/genai/models.py:4940, in Models._generate_content(self, model, contents, config)
#    4937 request_dict = _common.convert_to_dict(request_dict)
#    4938 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4940 response_dict = self._api_client.request(
#    4941     'post', path, request_dict, http_options
#    4942 )
#    4944 if self._api_client.vertexai:
#    4945   response_dict = _GenerateContentResponse_from_vertex(
#    4946       self._api_client, response_dict
#    4947   )
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:785, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#     775 def request(
#     776     self,
#     777     http_method: str,
#    (...)    780     http_options: Optional[HttpOptionsOrDict] = None,
#     781 ) -> Union[BaseResponse, Any]:
#     782   http_request = self._build_request(
#     783       http_method, path, request_dict, http_options
#     784   )
# --> 785   response = self._request(http_request, stream=False)
#     786   json_response = response.json
#     787   if not json_response:
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:707, in BaseApiClient._request(self, http_request, stream)
#     703   return HttpResponse(
#     704       response.headers, response if stream else [response.text]
#     705   )
#     706 else:
# --> 707   response = self._httpx_client.request(
#     708       method=http_request.method,
#     709       url=http_request.url,
#     710       headers=http_request.headers,
#     711       content=data,
#     712       timeout=http_request.timeout,
#     713   )
#     714   errors.APIError.raise_for_response(response)
#     715   return HttpResponse(
#     716       response.headers, response if stream else [response.text]
#     717   )
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Hackathon_JLR_2025/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.12/ssl.py:1233, in SSLSocket.recv(self, buflen, flags)
#    1229     if flags != 0:
#    1230         raise ValueError(
#    1231             "non-zero flags not allowed in calls to recv() on %s" %
#    1232             self.__class__)
# -> 1233     return self.read(buflen)
#    1234 else:
#    1235     return super().recv(buflen, flags)
#
# File /usr/lib/python3.12/ssl.py:1106, in SSLSocket.read(self, len, buffer)
#    1104         return self._sslobj.read(len, buffer)
#    1105     else:
# -> 1106         return self._sslobj.read(len)
#    1107 except SSLError as x:
#    1108     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
import json
with open('cwe_119_code_pairs.json', 'w') as f:
    json.dump(examples, f, indent=2, ensure_ascii=False)

# %%
from google import genai
from pydantic import BaseModel, Field

class AnalysisResponse(BaseModel):
    code_analysis: str = Field(
        ...,
        description="A detailed analysis of the code pair, including the vulnerability and its fix."
    )
    is_vulnerable: bool = Field(
        ...,
        description="Indicates whether the vulnerable code snippet contains a security flaw."
    )

def get_analysis_prompt(code_snippet: str, cwe_info = None):
    prompt = f"""
You are an expert code analyst specializing in automotive software security.
Your task is to analyze the provided code snippet and determine if it contains a security flaw.
The code snippet is in C / C++ programming language.
Here is the code snippet:
```
{code_snippet}
```
Provide a step by step thought process of how you arrived at your conclusion. Pretend that you did not know the problem from the beginning, but reached the conclusion after step by step analysis.
"""
    if cwe_info:
        prompt += f"""
Hint:
The code is vulnerable to {cwe_info}.
Pretend that you did not know the problem from the beginning, but reached the conclusion after step by step analysis.
"""
    return prompt.strip()

def analyze_code(code_snippet: str, cwe_info = None) -> AnalysisResponse:
    try:
        response = client.models.generate_content(
            model="gemini-2.5-flash-preview-05-20",
            contents=get_analysis_prompt(code_snippet, cwe_info),
            config={
                "response_mime_type": "application/json",
                "response_schema": AnalysisResponse,
            },
        )
        return response.parsed
    except genai.errors.ServerError as e:
        print(f"Server error: {e}")
        return None

# %%
vulnerable_code = examples[15]['vulnerable_code']
analysis = analyze_code(vulnerable_code, hash_map["119"])
if analysis:
    print(f"Vulnerable code snippet analysis for CWE-119:")
    print(f"{vulnerable_code}")
    print("===================================================")
    print("Analysis Response:")
    print("Code Analysis:")
    print(analysis.code_analysis)
    print(f"Is Vulnerable: {analysis.is_vulnerable}")
# Out:
# Vulnerable code snippet analysis for CWE-119:
# #include <stdint.h>
# #include <string.h>
#
# #define MAX_PACKET_SIZE 256
#
# #define ENGINE_CONFIG_SIZE 64
# #define TRANSMISSION_CONFIG_SIZE 32
# #define ADAS_CONFIG_SIZE 128
#
# typedef enum {
#     MODULE_ENGINE = 1,
#     MODULE_TRANSMISSION = 2,
#     MODULE_ADAS = 3
# } VehicleModuleId;
#
# typedef struct {
#     VehicleModuleId moduleId;
#     uint16_t configLength;
#     uint8_t configData[MAX_PACKET_SIZE - sizeof(VehicleModuleId) - sizeof(uint16_t)];
# } ModuleConfigPacket;
#
# static uint8_t g_engineConfig[ENGINE_CONFIG_SIZE];
# static uint8_t g_transmissionConfig[TRANSMISSION_CONFIG_SIZE];
# static uint8_t g_adasConfig[ADAS_CONFIG_SIZE];
#
# static uint16_t g_engineConfigCurrentLen = 0;
# static uint16_t g_transmissionConfigCurrentLen = 0;
# static uint16_t g_adasConfigCurrentLen = 0;
#
# void initModuleConfigs() {
#     memset(g_engineConfig, 0, ENGINE_CONFIG_SIZE);
#     memset(g_transmissionConfig, 0, TRANSMISSION_CONFIG_SIZE);
#     memset(g_adasConfig, 0, ADAS_CONFIG_SIZE);
#     g_engineConfigCurrentLen = 0;
#     g_transmissionConfigCurrentLen = 0;
#     g_adasConfigCurrentLen = 0;
# }
#
# void processModuleConfigurationVulnerable(const ModuleConfigPacket* packet, uint16_t packet_total_len) {
#     if (packet == NULL || packet_total_len < (sizeof(VehicleModuleId) + sizeof(uint16_t))) {
#         return;
#     }
#
#     uint16_t header_size = sizeof(VehicleModuleId) + sizeof(uint16_t);
#     uint16_t available_payload_in_packet = packet_total_len - header_size;
#
#     if (packet->configLength > available_payload_in_packet) {
#         return;
#     }
#
#     switch (packet->moduleId) {
#         case MODULE_ENGINE:
#             memcpy(g_engineConfig, packet->configData, packet->configLength);
#             g_engineConfigCurrentLen = packet->configLength;
#             break;
#         case MODULE_TRANSMISSION:
#             memcpy(g_transmissionConfig, packet->configData, packet->configLength);
#             g_transmissionConfigCurrentLen = packet->configLength;
#             break;
#         case MODULE_ADAS:
#             memcpy(g_adasConfig, packet->configData, packet->configLength);
#             g_adasConfigCurrentLen = packet->configLength;
#             break;
#         default:
#             break;
#     }
# }
# ===================================================
# Analysis Response:
# Code Analysis:
# The provided code implements a module configuration update mechanism. The `processModuleConfigurationVulnerable` function receives a `ModuleConfigPacket` and attempts to copy `configData` into one of three static global buffers (`g_engineConfig`, `g_transmissionConfig`, `g_adasConfig`) based on the `moduleId`.
#
# **Vulnerability:**
# CWE-119: Improper Restriction of Operations within the Bounds of a Memory Buffer (Buffer Overflow).
#
# The vulnerability lies in the `memcpy` operations. While the function performs checks to ensure that `packet->configLength` does not exceed the `available_payload_in_packet` (i.e., the actual data received within the packet), it **fails to check if `packet->configLength` exceeds the fixed size of the *destination* static buffers** (`g_engineConfig`, `g_transmissionConfig`, `g_adasConfig`).
#
# Let's break it down:
# 1.  The `ModuleConfigPacket` defines `configData` as an array with a maximum size of `MAX_PACKET_SIZE - sizeof(VehicleModuleId) - sizeof(uint16_t)`, which is `256 - (approx 1-4) - 2` bytes, effectively around 250-253 bytes. This means `packet->configLength` can be legitimately up to this size, assuming enough data is provided in the `packet_total_len`.
# 2.  The global configuration buffers have much smaller fixed sizes:
#     *   `g_engineConfig`: `ENGINE_CONFIG_SIZE` = 64 bytes
#     *   `g_transmissionConfig`: `TRANSMISSION_CONFIG_SIZE` = 32 bytes
#     *   `g_adasConfig`: `ADAS_CONFIG_SIZE` = 128 bytes
# 3.  Consider the `MODULE_TRANSMISSION` case: If an attacker sends a `ModuleConfigPacket` with `moduleId` set to `MODULE_TRANSMISSION` and `configLength` set to, for example, 100 bytes (which is less than the packet's `configData` capacity and `available_payload_in_packet`), the `memcpy(g_transmissionConfig, packet->configData, packet->configLength);` will attempt to copy 100 bytes into `g_transmissionConfig`, which only has a capacity of 32 bytes. This will result in a write of 68 bytes past the end of `g_transmissionConfig`, leading to a buffer overflow.
# 4.  Similar overflows can occur for `g_engineConfig` (if `configLength` > 64) and potentially `g_adasConfig` (if `configLength` > 128, up to ~253 bytes).
#
# **Impact:**
# This buffer overflow can lead to:
# *   **Data Corruption:** Overwriting adjacent memory regions, potentially corrupting other static variables or stack data.
# *   **Denial of Service (DoS):** Crashing the application due to memory access violations.
# *   **Arbitrary Code Execution:** In certain scenarios, an attacker might be able to overwrite function pointers, return addresses, or other control flow mechanisms, potentially leading to arbitrary code execution.
#
# **Fix:**
# To remediate this vulnerability, each `memcpy` operation must be guarded by a check that `packet->configLength` does not exceed the size of the *destination* buffer. The minimum of the `packet->configLength` and the actual destination buffer size should be used as the copy length.
#
# ```c
# void processModuleConfigurationSecure(const ModuleConfigPacket* packet, uint16_t packet_total_len) {
#     if (packet == NULL || packet_total_len < (sizeof(VehicleModuleId) + sizeof(uint16_t))) {
#         return;
#     }
#
#     uint16_t header_size = sizeof(VehicleModuleId) + sizeof(uint16_t);
#     uint16_t available_payload_in_packet = packet_total_len - header_size;
#
#     // Ensure configLength does not exceed the actual received payload
#     if (packet->configLength > available_payload_in_packet) {
#         // Optionally log or handle this error more specifically
#         return;
#     }
#
#     uint16_t bytes_to_copy = 0;
#
#     switch (packet->moduleId) {
#         case MODULE_ENGINE:
#             // Calculate the minimum of the requested length and the destination buffer's capacity
#             bytes_to_copy = (packet->configLength < ENGINE_CONFIG_SIZE) ? packet->configLength : ENGINE_CONFIG_SIZE;
#             memcpy(g_engineConfig, packet->configData, bytes_to_copy);
#             g_engineConfigCurrentLen = bytes_to_copy; // Update current length with actual copied bytes
#             break;
#         case MODULE_TRANSMISSION:
#             bytes_to_copy = (packet->configLength < TRANSMISSION_CONFIG_SIZE) ? packet->configLength : TRANSMISSION_CONFIG_SIZE;
#             memcpy(g_transmissionConfig, packet->configData, bytes_to_copy);
#             g_transmissionConfigCurrentLen = bytes_to_copy;
#             break;
#         case MODULE_ADAS:
#             bytes_to_copy = (packet->configLength < ADAS_CONFIG_SIZE) ? packet->configLength : ADAS_CONFIG_SIZE;
#             memcpy(g_adasConfig, packet->configData, bytes_to_copy);
#             g_adasConfigCurrentLen = bytes_to_copy;
#             break;
#         default:
#             // Handle unknown module ID, perhaps log or return an error
#             break;
#     }
# }
# ```
# This fix ensures that the amount of data copied into each global buffer never exceeds its declared size, preventing buffer overflows.
# Is Vulnerable: True
