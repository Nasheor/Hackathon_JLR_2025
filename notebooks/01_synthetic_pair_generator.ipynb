# %%
# Configuration
from pathlib import Path
import json

RAW_DATA_DIR = Path("../data/raw")
PROCESSED_DATA_DIR = Path("../data/processed")

# Read the CWE metadata file
hash_map = {}
with open(RAW_DATA_DIR / "cwec_metadata.json", "r") as f:
    hash_map = json.load(f)

# Initialize containers to hold examples and JSON output
examples = []
json_output_file = []


# Specify CWE-ID to use in generation here:
cwe_id = "119"

# Specify the target number of code pairs to generate
target_pairs_number = 5

# Verbose generation or not
verbose_generation = True

# Path to Gemini Token file
TOKEN_PATH = Path("token")

# Read the Gemini Token
with open(TOKEN_PATH, "r") as f:
    token = f.read().strip()

# Prepare / read the JSON output file
# Loads existing data or initializes a new structure
output_file_path = RAW_DATA_DIR / f"cwe_{cwe_id}_code_pairs.json"
if output_file_path.exists():
    with open(output_file_path, "r") as f:
        try:
            json_out_structure = json.load(f)
        except json.JSONDecodeError:
            json_out_structure = []
else:
    # create the file if it does not exist
    with open(output_file_path, "w") as f:
        json.dump([], f, indent=2, ensure_ascii=False)
    print(f"File {output_file_path} does not exist, creating...")


# Populate examples from the loaded JSON file
for item in json_out_structure:
    examples.append({'vulnerable_code': item['vulnerable_code'], 'fixed_code': item['fixed_code']})

# %%
# Prompt generation function
def generate_prompt(cwe_id: str, examples: list[dict] | None = None) -> str:
    prompt = f"""
You are a professional vulnerability researcher specializing in automotive software security.

Your task is to generate a C or C++ code pair demonstrating a security flaw and its corresponding fix, based on the provided CWE entry.

Requirements:

1. Each code pair must consist of:
   - A **vulnerable** code snippet that reflects the CWE in a subtle and realistic way.
   - A **corrected** code snippet that resolves the issue.

2. The vulnerable code must:
   - Be embedded within a **larger, non-trivial function or class**, not as a standalone fragment.
   - Be situated within a realistic **automotive software context**, using terminology and logic from real-world automotive domains such as (but not limited to):
    - **ECU firmware update handling**
    - **CAN/LIN/FlexRay communication parsing**
    - **ADAS sensor fusion**
    - **Infotainment system control**
    - **BMS (Battery Management System) parameter decoding**
    - **Vehicle diagnostics (UDS, OBD-II)**
    - **In-vehicle memory management (e.g., persistent flash, heap buffers)**
    - other automotive contexts, like **vehicle-to-everything (V2X) communication**, **powertrain control**, or **vehicle security protocols**, etc.
   - Use **authentic naming and structural patterns** consistent with automotive systems (e.g., `EcuMessage_t`, `applyDiagnosticPayload()`, `processCanFrame()`).
   - Introduce the vulnerability through complex control/data flow, indirection, or interaction between components — not through simple or obvious coding errors.

3. The fixed code should:
   - Preserve the surrounding structure and logic while removing or mitigating the vulnerability.
   - Maintain the same automotive context for consistency.

4. Output code structure:
   - The output code pair **MUST NOT** CONTAIN ANY COMMENTS or hints that indicate the presence of a vulnerability or its fix.

Context:
CWE Info: 
```
{hash_map.get(cwe_id)}
```
"""
    if examples:
        prompt += f"""
Here are some examples of previously generated code pairs for CWE-{cwe_id}.

Structural Diversity:
- Each new code pair must introduce a **distinct code structure** and vulnerability pattern, even if demonstrating the same CWE.
- Avoid reusing the same memory layout, control flow, and vulnerability location across examples.
- You must vary at least one of the following dimensions from previous examples:
  - Use of **different memory management approaches** (e.g., stack buffers, dynamic arrays, memory pools, shared memory, or DMA buffers).
  - Different **data structures** (e.g., nested structs, linked lists, ring buffers, or message queues).
  - Different **control flow complexity** (e.g., state machines, callbacks, conditionals, or recursive logic).
  - Split the vulnerability across **multiple functions, classes, or helper utilities**, instead of keeping it in one place.
  - Add **realistic domain-specific distractions** (e.g., logging, validation functions, state tracking, etc.) that make the vulnerability less obvious.
- Even if using the same unsafe function (e.g., `memcpy`), the **way it leads to the flaw must be significantly different** from prior examples.
```
{examples}
```
"""
    return prompt.strip()

# %%
# Gemini Initialisation

from pydantic import BaseModel, Field
from google import genai

# Initialize the Gemini client
client = genai.Client(api_key=token)

# Define the response model for the code pair
class CodePairResponse(BaseModel):
    cwe_id: str = Field(
        ...,
        description="The CWE ID associated with the code pair."
    )
    vulnerable_code: str = Field(
        ...,
        description="The vulnerable code snippet that contains a security flaw."
    )
    fixed_code: str = Field(
        ...,
        description="The fixed code snippet that resolves the security flaw."
    )

# Define the function to get a code pair based on the CWE ID
def get_code_pair(cwe_id: str, examples: dict | None = None) -> CodePairResponse:
    try:
        response = client.models.generate_content(
            model="gemini-2.5-flash-preview-05-20",
            contents=generate_prompt(cwe_id, examples),
            config={
                "response_mime_type": "application/json",
                "response_schema": CodePairResponse,
            },
        )
        # if server error, return empty list
    except genai.errors.ServerError as e:
        print(f"Server error: {e}")
        return None
    return response.parsed

# %%
import random
from pathlib import Path

def generate_code_pairs(cwe_id: str, target_pairs_number: int) -> list[dict]:
    if len(examples) >= target_pairs_number:
        print(f"Already have {len(examples)} examples, no need to generate more.")
        return # Return early if we already have enough examples
    print(f"Generate {target_pairs_number - len(examples)} more code pairs for CWE-{cwe_id}...")
    for i in range(target_pairs_number - len(examples)):
        pair = get_code_pair(cwe_id, random.choices(examples, k=8) if examples else None)
        if pair:
            examples.append({'vulnerable_code': pair.vulnerable_code, 'fixed_code': pair.fixed_code})
            if verbose_generation:
                print(f"Generated code pair {i + 1}:")
                print(f"CWE ID: {pair.cwe_id}")
                print("\nVulnerable Code:")
                print(pair.vulnerable_code)
                print("\nFixed Code:")
                print(pair.fixed_code)
                print("\n" + "="*50 + "\n")
            json_out_structure.append({
                "cwe_id": f"CWE-{cwe_id}",
                "cwe_description": hash_map[cwe_id]['Extended_Description'] if 'Extended_Description' in hash_map[cwe_id] else hash_map[cwe_id]['Description'],
                "vulnerable_code": pair.vulnerable_code,
                "fixed_code": pair.fixed_code,
            })
            with open(output_file_path, "w") as f:
                json.dump(json_out_structure, f, indent=2, ensure_ascii=False)
        else:
            print("Failed to retrieve code pair.")

# %%
# generate code pairs
generate_code_pairs(cwe_id, target_pairs_number)
# Out:
# Generate 5 more code pairs for CWE-119...
# Generated code pair 1:
# CWE ID: CWE-119
#
# Vulnerable Code:
# typedef unsigned char uint8_t;
# typedef unsigned int uint32_t;
#
# #define MAX_CAN_PAYLOAD_SIZE 8
# #define CONFIG_DATA_BUFFER_SIZE 32
#
# typedef struct {
#     uint32_t id;
#     uint8_t dlc;
#     uint8_t data[MAX_CAN_PAYLOAD_SIZE];
# } CanFrame_t;
#
# static uint8_t g_ecuConfigBuffer[CONFIG_DATA_BUFFER_SIZE];
#
# int processDiagnosticCanFrame(const CanFrame_t* frame) {
#     if (frame == NULL || frame->dlc == 0) {
#         return -1;
#     }
#
#     uint8_t serviceId = frame->data[0];
#
#     switch (serviceId) {
#         case 0x22: {
#             break;
#         }
#         case 0x2E: {
#             if (frame->dlc < 3) {
#                 return -2;
#             }
#             uint8_t targetOffset = frame->data[1];
#             uint8_t bytesToWrite = frame->data[2];
#
#             uint8_t actualPayloadStart = 3;
#             uint8_t availableDataInCanFrame = (frame->dlc > actualPayloadStart) ? (frame->dlc - actualPayloadStart) : 0;
#
#             uint8_t copyAmount = (bytesToWrite < availableDataInCanFrame) ? bytesToWrite : availableDataInCanFrame;
#
#             for (uint8_t i = 0; i < copyAmount; ++i) {
#                 g_ecuConfigBuffer[targetOffset + i] = frame->data[actualPayloadStart + i];
#             }
#             break;
#         }
#         default: {
#             return -99;
#         }
#     }
#     return 0;
# }
#
# Fixed Code:
# typedef unsigned char uint8_t;
# typedef unsigned int uint32_t;
#
# #define MAX_CAN_PAYLOAD_SIZE 8
# #define CONFIG_DATA_BUFFER_SIZE 32
#
# typedef struct {
#     uint32_t id;
#     uint8_t dlc;
#     uint8_t data[MAX_CAN_PAYLOAD_SIZE];
# } CanFrame_t;
#
# static uint8_t g_ecuConfigBuffer[CONFIG_DATA_BUFFER_SIZE];
#
# int processDiagnosticCanFrame(const CanFrame_t* frame) {
#     if (frame == NULL || frame->dlc == 0) {
#         return -1;
#     }
#
#     uint8_t serviceId = frame->data[0];
#
#     switch (serviceId) {
#         case 0x22: {
#             break;
#         }
#         case 0x2E: {
#             if (frame->dlc < 3) {
#                 return -2;
#             }
#             uint8_t targetOffset = frame->data[1];
#             uint8_t bytesToWrite = frame->data[2];
#
#             uint8_t actualPayloadStart = 3;
#             uint8_t availableDataInCanFrame = (frame->dlc > actualPayloadStart) ? (frame->dlc - actualPayloadStart) : 0;
#
#             uint8_t copyAmount = (bytesToWrite < availableDataInCanFrame) ? bytesToWrite : availableDataInCanFrame;
#
#             if (targetOffset >= CONFIG_DATA_BUFFER_SIZE) {
#                 return -4;
#             }
#             if (targetOffset + copyAmount > CONFIG_DATA_BUFFER_SIZE) {
#                 copyAmount = CONFIG_DATA_BUFFER_SIZE - targetOffset;
#             }
#
#             for (uint8_t i = 0; i < copyAmount; ++i) {
#                 g_ecuConfigBuffer[targetOffset + i] = frame->data[actualPayloadStart + i];
#             }
#             break;
#         }
#         default: {
#             return -99;
#         }
#     }
#     return 0;
# }
#
# ==================================================
#
# Generated code pair 2:
# CWE ID: 119
#
# Vulnerable Code:
# typedef unsigned char uint8_t;
# typedef unsigned int uint32_t;
# typedef unsigned short uint16_t;
#
# #define MAX_SENSOR_PACKET_DATA_SIZE 256
# #define PROCESSING_BUFFER_SIZE 128
# #define ADAS_CONTROLLER_ID 0x10
#
# typedef struct {
#     uint16_t sensorId;
#     uint32_t timestamp;
#     uint16_t payloadLength;
#     uint8_t data[MAX_SENSOR_PACKET_DATA_SIZE];
# } SensorDataPacket_t;
#
# static uint8_t g_fusionOutputData[PROCESSING_BUFFER_SIZE];
#
# int updateFusionAlgorithm(const SensorDataPacket_t* packet) {
#     if (packet == NULL || packet->payloadLength == 0) {
#         return -1;
#     }
#
#     if (packet->sensorId != ADAS_CONTROLLER_ID) {
#         return -2;
#     }
#
#     uint8_t tempProcessingBuffer[PROCESSING_BUFFER_SIZE];
#
#     memcpy(tempProcessingBuffer, packet->data, packet->payloadLength);
#
#     for (uint16_t i = 0; i < packet->payloadLength; ++i) {
#         tempProcessingBuffer[i] = tempProcessingBuffer[i] ^ 0x55;
#     }
#
#     memcpy(g_fusionOutputData, tempProcessingBuffer, PROCESSING_BUFFER_SIZE);
#
#     return 0;
# }
#
# Fixed Code:
# typedef unsigned char uint8_t;
# typedef unsigned int uint32_t;
# typedef unsigned short uint16_t;
#
# #define MAX_SENSOR_PACKET_DATA_SIZE 256
# #define PROCESSING_BUFFER_SIZE 128
# #define ADAS_CONTROLLER_ID 0x10
#
# typedef struct {
#     uint16_t sensorId;
#     uint32_t timestamp;
#     uint16_t payloadLength;
#     uint8_t data[MAX_SENSOR_PACKET_DATA_SIZE];
# } SensorDataPacket_t;
#
# static uint8_t g_fusionOutputData[PROCESSING_BUFFER_SIZE];
#
# int updateFusionAlgorithm(const SensorDataPacket_t* packet) {
#     if (packet == NULL || packet->payloadLength == 0) {
#         return -1;
#     }
#
#     if (packet->sensorId != ADAS_CONTROLLER_ID) {
#         return -2;
#     }
#
#     uint8_t tempProcessingBuffer[PROCESSING_BUFFER_SIZE];
#
#     uint16_t bytesToCopy = packet->payloadLength;
#     if (bytesToCopy > PROCESSING_BUFFER_SIZE) {
#         bytesToCopy = PROCESSING_BUFFER_SIZE;
#     }
#
#     memcpy(tempProcessingBuffer, packet->data, bytesToCopy);
#
#     for (uint16_t i = 0; i < bytesToCopy; ++i) {
#         tempProcessingBuffer[i] = tempProcessingBuffer[i] ^ 0x55;
#     }
#
#     memcpy(g_fusionOutputData, tempProcessingBuffer, bytesToCopy);
#
#     return 0;
# }
#
# ==================================================
#
# Generated code pair 3:
# CWE ID: CWE-119
#
# Vulnerable Code:
# typedef unsigned char uint8_t;
# typedef unsigned short uint16_t;
# typedef unsigned int uint32_t;
#
# #define MAX_V2X_PAYLOAD_SIZE 512
# #define VEHICLE_STATUS_BUFFER_SIZE 64
#
# enum V2XMessageType {
#     MSG_TYPE_BROADCAST = 0x01,
#     MSG_TYPE_VEHICLE_STATUS = 0x02,
#     MSG_TYPE_SECURE_PAYMENT = 0x03
# };
#
# typedef struct {
#     uint8_t  messageType;
#     uint16_t totalLength;
#     uint16_t sequenceNum;
#     uint32_t checksum;
# } V2XHeader_t;
#
# class V2XMessageParser {
# private:
#     uint8_t m_vehicleStatusData[VEHICLE_STATUS_BUFFER_SIZE];
#     bool m_statusDataValid;
#
#     void logError(const char* msg) {
#         (void)msg;
#     }
#
# public:
#     V2XMessageParser() : m_statusDataValid(false) {}
#
#     int parseMessage(const uint8_t* rawMessage, uint16_t rawMessageLen) {
#         if (rawMessage == NULL || rawMessageLen < sizeof(V2XHeader_t)) {
#             logError("Invalid message or length.");
#             return -1;
#         }
#
#         V2XHeader_t header;
#         memcpy(&header, rawMessage, sizeof(V2XHeader_t));
#
#         if (header.totalLength != rawMessageLen) {
#             logError("Message length mismatch.");
#             return -2;
#         }
#
#         uint8_t* payloadPtr = (uint8_t*)(rawMessage + sizeof(V2XHeader_t));
#         uint16_t payloadLen = rawMessageLen - sizeof(V2XHeader_t);
#
#         switch (header.messageType) {
#             case MSG_TYPE_BROADCAST:
#                 break;
#
#             case MSG_TYPE_VEHICLE_STATUS:
#                 if (payloadLen < (sizeof(uint8_t) + sizeof(uint16_t))) {
#                     logError("Vehicle status payload too short.");
#                     return -3;
#                 }
#
#                 uint8_t statusType = payloadPtr[0];
#                 uint16_t dataLength = *(uint16_t*)(payloadPtr + sizeof(uint8_t));
#
#                 uint8_t* statusDataPtr = payloadPtr + sizeof(uint8_t) + sizeof(uint16_t);
#                 uint16_t remainingPayload = payloadLen - (sizeof(uint8_t) + sizeof(uint16_t));
#
#                 if (dataLength > remainingPayload) {
#                     logError("Declared dataLength exceeds actual remaining payload.");
#                     return -4;
#                 }
#
#                 memcpy(m_vehicleStatusData, statusDataPtr, dataLength);
#                 m_statusDataValid = true;
#                 break;
#
#             case MSG_TYPE_SECURE_PAYMENT:
#                 break;
#
#             default:
#                 logError("Unknown message type.");
#                 return -99;
#         }
#         return 0;
#     }
#
#     const uint8_t* getVehicleStatusData() const {
#         return m_vehicleStatusData;
#     }
#
#     bool isStatusDataValid() const {
#         return m_statusDataValid;
#     }
# };
#
# Fixed Code:
# typedef unsigned char uint8_t;
# typedef unsigned short uint16_t;
# typedef unsigned int uint32_t;
#
# #define MAX_V2X_PAYLOAD_SIZE 512
# #define VEHICLE_STATUS_BUFFER_SIZE 64
#
# enum V2XMessageType {
#     MSG_TYPE_BROADCAST = 0x01,
#     MSG_TYPE_VEHICLE_STATUS = 0x02,
#     MSG_TYPE_SECURE_PAYMENT = 0x03
# };
#
# typedef struct {
#     uint8_t  messageType;
#     uint16_t totalLength;
#     uint16_t sequenceNum;
#     uint32_t checksum;
# } V2XHeader_t;
#
# class V2XMessageParser {
# private:
#     uint8_t m_vehicleStatusData[VEHICLE_STATUS_BUFFER_SIZE];
#     bool m_statusDataValid;
#
#     void logError(const char* msg) {
#         (void)msg;
#     }
#
# public:
#     V2XMessageParser() : m_statusDataValid(false) {}
#
#     int parseMessage(const uint8_t* rawMessage, uint16_t rawMessageLen) {
#         if (rawMessage == NULL || rawMessageLen < sizeof(V2XHeader_t)) {
#             logError("Invalid message or length.");
#             return -1;
#         }
#
#         V2XHeader_t header;
#         memcpy(&header, rawMessage, sizeof(V2XHeader_t));
#
#         if (header.totalLength != rawMessageLen) {
#             logError("Message length mismatch.");
#             return -2;
#         }
#
#         uint8_t* payloadPtr = (uint8_t*)(rawMessage + sizeof(V2XHeader_t));
#         uint16_t payloadLen = rawMessageLen - sizeof(V2XHeader_t);
#
#         switch (header.messageType) {
#             case MSG_TYPE_BROADCAST:
#                 break;
#
#             case MSG_TYPE_VEHICLE_STATUS:
#                 if (payloadLen < (sizeof(uint8_t) + sizeof(uint16_t))) {
#                     logError("Vehicle status payload too short.");
#                     return -3;
#                 }
#
#                 uint8_t statusType = payloadPtr[0];
#                 uint16_t dataLength = *(uint16_t*)(payloadPtr + sizeof(uint8_t));
#
#                 uint8_t* statusDataPtr = payloadPtr + sizeof(uint8_t) + sizeof(uint16_t);
#                 uint16_t remainingPayload = payloadLen - (sizeof(uint8_t) + sizeof(uint16_t));
#
#                 if (dataLength > remainingPayload) {
#                     logError("Declared dataLength exceeds actual remaining payload.");
#                     return -4;
#                 }
#
#                 uint16_t copySize = dataLength;
#                 if (copySize > VEHICLE_STATUS_BUFFER_SIZE) {
#                     copySize = VEHICLE_STATUS_BUFFER_SIZE;
#                     logError("Vehicle status data too large, truncated.");
#                 }
#                 memcpy(m_vehicleStatusData, statusDataPtr, copySize);
#                 m_statusDataValid = true;
#                 break;
#
#             case MSG_TYPE_SECURE_PAYMENT:
#                 break;
#
#             default:
#                 logError("Unknown message type.");
#                 return -99;
#         }
#         return 0;
#     }
#
#     const uint8_t* getVehicleStatusData() const {
#         return m_vehicleStatusData;
#     n    bool isStatusDataValid() const {
#         return m_statusDataValid;
#     }
# };
#
# ==================================================
#
# Generated code pair 4:
# CWE ID: CWE-119
#
# Vulnerable Code:
# #include <string.h>
#
# typedef unsigned char uint8_t;
# typedef unsigned short uint16_t;
# typedef unsigned int uint32_t;
# typedef unsigned long long uint64_t;
#
# #define PERSISTENT_CONFIG_FLASH_SIZE 2048
# #define DIAG_RESPONSE_MAX_PAYLOAD 256
#
# static uint8_t s_persistentConfigFlash[PERSISTENT_CONFIG_FLASH_SIZE];
#
# class DiagnosticServiceHandler {
# public:
#     DiagnosticServiceHandler() {
#         for (uint16_t i = 0; i < PERSISTENT_CONFIG_FLASH_SIZE; ++i) {
#             s_persistentConfigFlash[i] = (uint8_t)(i % 0xFF);
#         }
#     }
#
#     int handleReadMemoryByAddress(const uint8_t* payload, uint16_t payloadLen,
#                                   uint8_t* responseBuffer, uint16_t responseBufferMaxLen) {
#         if (payload == NULL || payloadLen < 6 || responseBuffer == NULL) {
#             return -1;
#         }
#
#         if (payload[0] != 0x23) {
#             return -2;
#         }
#
#         uint32_t address = ((uint32_t)payload[1] << 16) | ((uint32_t)payload[2] << 8) | payload[3];
#         uint16_t length = ((uint16_t)payload[4] << 8) | payload[5];
#
#         if (address >= PERSISTENT_CONFIG_FLASH_SIZE) {
#             return -3;
#         }
#
#         if ((uint64_t)address + length > PERSISTENT_CONFIG_FLASH_SIZE) {
#             length = PERSISTENT_CONFIG_FLASH_SIZE - address;
#         }
#
#         memcpy(responseBuffer, &s_persistentConfigFlash[address], length);
#
#         return length;
#     }
# };
#
#
# Fixed Code:
# #include <string.h>
#
# typedef unsigned char uint8_t;
# typedef unsigned short uint16_t;
# typedef unsigned int uint32_t;
# typedef unsigned long long uint64_t;
#
# #define PERSISTENT_CONFIG_FLASH_SIZE 2048
# #define DIAG_RESPONSE_MAX_PAYLOAD 256
#
# static uint8_t s_persistentConfigFlash[PERSISTENT_CONFIG_FLASH_SIZE];
#
# class DiagnosticServiceHandler {
# public:
#     DiagnosticServiceHandler() {
#         for (uint16_t i = 0; i < PERSISTENT_CONFIG_FLASH_SIZE; ++i) {
#             s_persistentConfigFlash[i] = (uint8_t)(i % 0xFF);
#         }
#     }
#
#     int handleReadMemoryByAddress(const uint8_t* payload, uint16_t payloadLen,
#                                   uint8_t* responseBuffer, uint16_t responseBufferMaxLen) {
#         if (payload == NULL || payloadLen < 6 || responseBuffer == NULL) {
#             return -1;
#         }
#
#         if (payload[0] != 0x23) {
#             return -2;
#         }
#
#         uint32_t address = ((uint32_t)payload[1] << 16) | ((uint32_t)payload[2] << 8) | payload[3];
#         uint16_t length = ((uint16_t)payload[4] << 8) | payload[5];
#
#         if (address >= PERSISTENT_CONFIG_FLASH_SIZE) {
#             return -3;
#         }
#
#         if ((uint64_t)address + length > PERSISTENT_CONFIG_FLASH_SIZE) {
#             length = PERSISTENT_CONFIG_FLASH_SIZE - address;
#         }
#
#         if (length > responseBufferMaxLen) {
#             length = responseBufferMaxLen;
#         }
#
#         memcpy(responseBuffer, &s_persistentConfigFlash[address], length);
#
#         return length;
#     }
# };
#
#
# ==================================================
#
# Generated code pair 5:
# CWE ID: 119
#
# Vulnerable Code:
# typedef unsigned char uint8_t;
# typedef unsigned short uint16_t;
# typedef unsigned int uint32_t;
#
# #define FIRMWARE_IMAGE_MAX_SIZE 0x8000
# #define FIRMWARE_CHUNK_MAX_DATA_SIZE 256
#
# typedef struct {
#     uint32_t expectedTotalSize;
#     uint32_t receivedSize;
#     uint32_t currentChecksum;
#     uint8_t updateInProgress;
# } FirmwareUpdateContext_t;
#
# static uint8_t s_firmwareImageBuffer[FIRMWARE_IMAGE_MAX_SIZE];
# static FirmwareUpdateContext_t s_fwUpdateContext;
#
# class EcuFirmwareUpdater {
# private:
#     void logError(const char* msg) {
#     }
#
# public:
#     EcuFirmwareUpdater() {
#         s_fwUpdateContext.expectedTotalSize = 0;
#         s_fwUpdateContext.receivedSize = 0;
#         s_fwUpdateContext.currentChecksum = 0;
#         s_fwUpdateContext.updateInProgress = 0;
#     }
#
#     int startFirmwareUpdate(uint32_t totalSize) {
#         if (s_fwUpdateContext.updateInProgress) {
#             logError("Update already in progress.");
#             return -1;
#         }
#         if (totalSize == 0 || totalSize > FIRMWARE_IMAGE_MAX_SIZE) {
#             logError("Invalid total firmware size.");
#             return -2;
#         }
#         s_fwUpdateContext.expectedTotalSize = totalSize;
#         s_fwUpdateContext.receivedSize = 0;
#         s_fwUpdateContext.currentChecksum = 0;
#         s_fwUpdateContext.updateInProgress = 1;
#         return 0;
#     }
#
#     int receiveFirmwareChunk(uint32_t chunk_offset, uint16_t chunk_length, const uint8_t* chunk_data) {
#         if (!s_fwUpdateContext.updateInProgress) {
#             logError("No update in progress.");
#             return -1;
#         }
#         if (chunk_data == NULL || chunk_length == 0 || chunk_length > FIRMWARE_CHUNK_MAX_DATA_SIZE) {
#             logError("Invalid chunk data or length.");
#             return -2;
#         }
#         if (chunk_offset >= s_fwUpdateContext.expectedTotalSize) {
#             logError("Chunk offset out of bounds of expected total size.");
#             return -3;
#         }
#
#         memcpy(&s_firmwareImageBuffer[chunk_offset], chunk_data, chunk_length);
#
#         s_fwUpdateContext.receivedSize += chunk_length;
#
#         return 0;
#     }
#
#     int finalizeFirmwareUpdate(uint32_t finalChecksum) {
#         if (!s_fwUpdateContext.updateInProgress) {
#             logError("No update in progress to finalize.");
#             return -1;
#         }
#         if (s_fwUpdateContext.receivedSize != s_fwUpdateContext.expectedTotalSize) {
#             logError("Incomplete firmware image received.");
#             return -2;
#         }
#         if (s_fwUpdateContext.currentChecksum != finalChecksum) {
#         }
#
#         s_fwUpdateContext.updateInProgress = 0;
#         return 0;
#     }
#
#     const uint8_t* getFirmwareImage() const {
#         return s_firmwareImageBuffer;
#     }
# };
#
# Fixed Code:
# typedef unsigned char uint8_t;
# typedef unsigned short uint16_t;
# typedef unsigned int uint32_t;
#
# #define FIRMWARE_IMAGE_MAX_SIZE 0x8000
# #define FIRMWARE_CHUNK_MAX_DATA_SIZE 256
#
# typedef struct {
#     uint32_t expectedTotalSize;
#     uint32_t receivedSize;
#     uint32_t currentChecksum;
#     uint8_t updateInProgress;
# } FirmwareUpdateContext_t;
#
# static uint8_t s_firmwareImageBuffer[FIRMWARE_IMAGE_MAX_SIZE];
# static FirmwareUpdateContext_t s_fwUpdateContext;
#
# class EcuFirmwareUpdater {
# private:
#     void logError(const char* msg) {
#     }
#
# public:
#     EcuFirmwareUpdater() {
#         s_fwUpdateContext.expectedTotalSize = 0;
#         s_fwUpdateContext.receivedSize = 0;
#         s_fwUpdateContext.currentChecksum = 0;
#         s_fwUpdateContext.updateInProgress = 0;
#     }
#
#     int startFirmwareUpdate(uint32_t totalSize) {
#         if (s_fwUpdateContext.updateInProgress) {
#             logError("Update already in progress.");
#             return -1;
#         }
#         if (totalSize == 0 || totalSize > FIRMWARE_IMAGE_MAX_SIZE) {
#             logError("Invalid total firmware size.");
#             return -2;
#         }
#         s_fwUpdateContext.expectedTotalSize = totalSize;
#         s_fwUpdateContext.receivedSize = 0;
#         s_fwUpdateContext.currentChecksum = 0;
#         s_fwUpdateContext.updateInProgress = 1;
#         return 0;
#     }
#
#     int receiveFirmwareChunk(uint32_t chunk_offset, uint16_t chunk_length, const uint8_t* chunk_data) {
#         if (!s_fwUpdateContext.updateInProgress) {
#             logError("No update in progress.");
#             return -1;
#         }
#         if (chunk_data == NULL || chunk_length == 0 || chunk_length > FIRMWARE_CHUNK_MAX_DATA_SIZE) {
#             logError("Invalid chunk data or length.");
#             return -2;
#         }
#         if (chunk_offset >= s_fwUpdateContext.expectedTotalSize) {
#             logError("Chunk offset out of bounds of expected total size.");
#             return -3;
#         }
#
#         uint32_t bytesToCopy = chunk_length;
#         if (chunk_offset + bytesToCopy > FIRMWARE_IMAGE_MAX_SIZE) {
#             if (chunk_offset >= FIRMWARE_IMAGE_MAX_SIZE) {
#                  logError("Chunk offset itself out of physical buffer bounds.");
#                  return -4;
#             }
#             bytesToCopy = FIRMWARE_IMAGE_MAX_SIZE - chunk_offset;
#             logError("Chunk copy truncated due to physical buffer size.");
#         }
#
#         memcpy(&s_firmwareImageBuffer[chunk_offset], chunk_data, bytesToCopy);
#
#         s_fwUpdateContext.receivedSize += bytesToCopy;
#
#         return 0;
#     }
#
#     int finalizeFirmwareUpdate(uint32_t finalChecksum) {
#         if (!s_fwUpdateContext.updateInProgress) {
#             logError("No update in progress to finalize.");
#             return -1;
#         }
#         if (s_fwUpdateContext.receivedSize != s_fwUpdateContext.expectedTotalSize) {
#             logError("Incomplete firmware image received.");
#             return -2;
#         }
#         if (s_fwUpdateContext.currentChecksum != finalChecksum) {
#         }
#
#         s_fwUpdateContext.updateInProgress = 0;
#         return 0;
#     }
#
#     const uint8_t* getFirmwareImage() const {
#         return s_firmwareImageBuffer;
#     }
# };
#
# ==================================================
